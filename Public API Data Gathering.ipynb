# %% [markdown]
# #Python Language  + Data Gathering
#
# ## Objectives
#
# * Retrieve data from a public API
# * Manipulate nested data structures: JSON
# * Use python lists and dictionaries
# * Make python functions

# %% [markdown]
# ## API: Application programming interface
#
# _"a set of clearly defined methods of communication between various software components."_

# %%
# %%html
# <iframe width="560" height="315" src="https://www.youtube.com/embed/s7wmiS2mSXY" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/s7wmiS2mSXY" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# Example of different parts to define an API:
# * A protocol (eg: `https`)
# * A server (eg: `httpbin.org`)
# * A method name / location (eg: `/get`)
# * A set of arguments (eg: `hello=world` and `foo=bar`)
#
# ➥ `https://httpbin.org/get?hello=world&foo=bar`

# %% [markdown]
# ## Villo API
#
# We will be using an API that provides information about the Villo stations and bike availability in Brussels. The API is documented on the [OpenDataSoft](https://public.opendatasoft.com/explore/dataset/jcdecaux-bike-stations-data-rt/information/) website.
#
# ![villo_photo](http://2.bp.blogspot.com/_EedX2cyld30/TTbxocuUIGI/AAAAAAAAAcY/v_uETl4Vntg/s1600/IMG_3964.JPG)

# %%
# %%html
# <iframe src="https://public.opendatasoft.com/explore/dataset/jcdecaux-bike-stations-data-rt/information/" style="width: 100%; height: 800px"></iframe>
# Out:
# <iframe src="https://public.opendatasoft.com/explore/dataset/jcdecaux-bike-stations-data-rt/information/" style="width: 100%; height: 800px"></iframe>

# %% [markdown]
# ## Let's retrive the information from the Villo API in this notebook
#
# The library [requests](http://docs.python-requests.org/en/master/) makes retrieving data in Python pretty easy. We will start by defining the url of the API:

# %%
URL_Villo = "https://public.opendatasoft.com/api/records/1.0/search/?dataset=jcdecaux-bike-stations-data-rt&q=&facet=banking&facet=name&exclude.name=BORNE+TEST+ALLEE+VERTE&exclude.name=BORNE+ATELIER+MECANOS+SPL&facet=bonus&facet=status&facet=contract_name&refine.contract_name=Bruxelles-Capitale&rows=50"

# %% [markdown]
# Note: You may have to use a different value for `URL_Villo` if the
# default arguments are not sufficient for your query.

# %%
import requests
response = requests.get(URL_Villo)
display(response)
# Out:
# <Response [200]>

# %% [markdown]
# ## What is this &lt;Response 200&gt; ?
#
# Have a look at the [HTTP Status Codes](http://www.restapitutorial.com/httpstatuscodes.html) to understand these _Error 404_ or _Error 500_ you may have seen on the web.

# %%
response.status_code
# Out:
# 200

# %%
# Show the error message if the retrieval failed for some reason:
if response.status_code == 200:
    print("The request went fine.")
else:
    print('There was a problem with the request')
# Out:
# The request went fine.

# %% [markdown]
# Let's now see what is inside the response we got:

# %%
response.content
# Out:
# b'{"nhits": 351, "parameters": {"dataset": "jcdecaux-bike-stations-data-rt", "rows": 50, "start": 0, "facet": ["banking", "name", "bonus", "status", "contract_name"], "format": "json", "timezone": "UTC"}, "records": [{"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "6e8b2f6a144a66d65da8d2974bd1a4db0eee4841", "fields": {"available_bike_stands": 12, "bike_stands": 25, "number": 305, "address": "PETER BENOIT - PLACE PETER BENOIT PLAATS 2-4", "name": "305 - PETER BENOIT", "bonus": "False", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 12, "position": [50.895592, 4.387965], "last_update": "2024-02-26T12:45:24+00:00"}, "geometry": {"type": "Point", "coordinates": [4.387965, 50.895592]}}, {"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "39042b9903ec9a87d9fd670c5999fb52ad8d9e6d", "fields": {"available_bike_stands": 11, "bike_stands": 25, "number": 200, "address": "VETERANS COLONIAUX / KOLONIALE VETERANEN - BD JULES GRAINDOR / JULES GRAINDORLAAN", "name": "200 - VETERANS COLONIAUX / KOLONIALE VETERANEN", "bonus": "True", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 14, "position": [50.843967, 4.313537], "last_update": "2024-02-26T12:46:03+00:00"}, "geometry": {"type": "Point", "coordinates": [4.313537, 50.843967]}}, {"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "f6039901b8d09af2397b1edf8f6c805fa99be5e4", "fields": {"available_bike_stands": 14, "bike_stands": 25, "number": 43, "address": "JOSEPH II/JOZEF II - RUE JOSEPH II/JOZEF II-STRAAT", "name": "043 - JOSEPH II / JOZEF II", "bonus": "False", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 11, "position": [50.845256, 4.374501], "last_update": "2024-02-26T12:46:42+00:00"}, "geometry": {"type": "Point", "coordinates": [4.374501, 50.845256]}}, {"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "89468bd2064d390b18663917ff6ec2aef6318f05", "fields": {"available_bike_stands": 9, "bike_stands": 25, "number": 271, "address": "DUBOIS - BD EMILE MACHTENS/LAAN 102-104", "name": "271 - DUBOIS", "bonus": "False", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 15, "position": [50.851158, 4.309591], "last_update": "2024-02-26T12:46:37+00:00"}, "geometry": {"type": "Point", "coordinates": [4.309591, 50.851158]}}, {"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "fdbf237799778416d27a384011b8e3844e61eff8", "fields": {"available_bike_stands": 19, "bike_stands": 25, "number": 131, "address": "JARDIN MASSART - AV HERMANN DEBROUXLAAN", "name": "131 - JARDIN MASSART", "bonus": "False", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 5, "position": [50.81329, 4.434751], "last_update": "2024-02-26T12:46:42+00:00"}, "geometry": {"type": "Point", "coordinates": [4.434751, 50.81329]}}, {"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "614111dc8bb4d50ca6cbbd9fe20f7d014cbaee80", "fields": {"available_bike_stands": 21, "bike_stands": 30, "number": 214, "address": "CAMPUS CERIA / CAMPUS VAN CERIA - AV EMILE GRYSON (FACE 6 a 10) / EMILE GRYSONLAAN (TEGENOVER 6 tot 10)", "name": "214 - CAMPUS CERIA / CAMPUS VAN CERIA", "bonus": "True", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 9, "position": [50.816002, 4.295121], "last_update": "2024-02-26T12:46:46+00:00"}, "geometry": {"type": "Point", "coordinates": [4.295121, 50.816002]}}, {"datasetid": "jcdecaux-bike-stations-data-rt", "recordid": "ba8d1161f59cd55b73aef06c2a8cfe5bcdaa9531", "fields": {"available_bike_stands": 12, "bike_stands": 20, "number": 343, "address": "VANDENDRIESCH - RUE J-B VANDENDRIESCH 22-24", "name": "343 - VANDENDRIESCH", "bonus": "False", "banking": "False", "contract_name": "Bruxelles-Capitale", "status": "OPEN", "available_bikes": 8, "position": [50.861788, 4.292913], "last_update": "202 ...

# %% [markdown]
# When looking at the content of the response, we can see it that it looks like Python dictionaries and lists, and it is probably encoded in [JSON (JavaScript Object Notation)](https://www.json.org/). The other popular formats for data structure are XML (mainly old stuff) and CSV (spreadsheet compatible).

# %% [markdown]
# Let's try parsing the data as if it were JSON, in order to get it as imbricated dictionaries and lists.  `requests` contains a shortcut do do this.

# %%
data = response.json()
data
# Out:
# {'nhits': 351,
#  'parameters': {'dataset': 'jcdecaux-bike-stations-data-rt',
#   'rows': 50,
#   'start': 0,
#   'facet': ['banking', 'name', 'bonus', 'status', 'contract_name'],
#   'format': 'json',
#   'timezone': 'UTC'},
#  'records': [{'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '6e8b2f6a144a66d65da8d2974bd1a4db0eee4841',
#    'fields': {'available_bike_stands': 12,
#     'bike_stands': 25,
#     'number': 305,
#     'address': 'PETER BENOIT - PLACE PETER BENOIT PLAATS 2-4',
#     'name': '305 - PETER BENOIT',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 12,
#     'position': [50.895592, 4.387965],
#     'last_update': '2024-02-26T12:45:24+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.387965, 50.895592]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '39042b9903ec9a87d9fd670c5999fb52ad8d9e6d',
#    'fields': {'available_bike_stands': 11,
#     'bike_stands': 25,
#     'number': 200,
#     'address': 'VETERANS COLONIAUX / KOLONIALE VETERANEN - BD JULES GRAINDOR / JULES GRAINDORLAAN',
#     'name': '200 - VETERANS COLONIAUX / KOLONIALE VETERANEN',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.843967, 4.313537],
#     'last_update': '2024-02-26T12:46:03+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.313537, 50.843967]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'f6039901b8d09af2397b1edf8f6c805fa99be5e4',
#    'fields': {'available_bike_stands': 14,
#     'bike_stands': 25,
#     'number': 43,
#     'address': 'JOSEPH II/JOZEF II - RUE JOSEPH II/JOZEF II-STRAAT',
#     'name': '043 - JOSEPH II / JOZEF II',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 11,
#     'position': [50.845256, 4.374501],
#     'last_update': '2024-02-26T12:46:42+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.374501, 50.845256]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '89468bd2064d390b18663917ff6ec2aef6318f05',
#    'fields': {'available_bike_stands': 9,
#     'bike_stands': 25,
#     'number': 271,
#     'address': 'DUBOIS - BD EMILE MACHTENS/LAAN 102-104',
#     'name': '271 - DUBOIS',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 15,
#     'position': [50.851158, 4.309591],
#     'last_update': '2024-02-26T12:46:37+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.309591, 50.851158]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'fdbf237799778416d27a384011b8e3844e61eff8',
#    'fields': {'available_bike_stands': 19,
#     'bike_stands': 25,
#     'number': 131,
#     'address': 'JARDIN MASSART - AV HERMANN DEBROUXLAAN',
#     'name': '131 - JARDIN MASSART',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 5,
#     'position': [50.81329, 4.434751],
#     'last_update': '2024-02-26T12:46:42+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.434751, 50.81329]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '614111dc8bb4d50ca6cbbd9fe20f7d014cbaee80',
#    'fields': {'available_bike_stands': 21,
#     'bike_stands': 30,
#     'number': 214,
#     'address': 'CAMPUS CERIA / CAMPUS VAN CERIA - AV EMILE GRYSON (FACE 6 a 10) / EMILE GRYSONLAAN (TEGENOVER 6 tot 10)',
#     'name': '214 - CAMPUS CERIA / CAMPUS VAN CERIA',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.816002, 4.295121],
#     'last_update': '2024-02-26T12:46:46+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.295121, 50.816002]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'ba8d1161f59cd55b73aef06c2a8cfe5bcdaa9531',
#    'fields': {'available_bike_stands': 12,
#     'bike_stands': 20,
#     'number': 343,
#     'address': 'VANDENDRIESCH - RUE J-B VANDENDRIESCH 22-24',
#     'name': '343 - VANDENDRIESCH',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 8,
#     'position': [50.861788, 4.292913],
#     'last_update': '2024-02-26T12:45:51+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.292913, 50.861788]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '92ca851251195416b0f7f203cd8a19214e4a55ca',
#    'fields': {'available_bike_stands': 16,
#     'bike_stands': 25,
#     'number': 207,
#     'address': 'BIESTEBROECK / BIESTEBROEK - CHEE DE MONS (FACE AU 518-526) / BERGENSESTEENWEG (TEGENOVER 518-526)',
#     'name': '207 - BIESTEBROECK / BIESTEBROEK',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 8,
#     'position': [50.833424, 4.313378],
#     'last_update': '2024-02-26T12:46:36+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.313378, 50.833424]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '0e567ef66cc50a463700c462cd3673a903904497',
#    'fields': {'available_bike_stands': 7,
#     'bike_stands': 35,
#     'number': 34,
#     'address': 'FONTAINAS - BLD ANSPACH N°180 A 192/ANSPACHLAAN N°180 TOT 192',
#     'name': '034 - FONTAINAS',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 28,
#     'position': [50.84563, 4.346942],
#     'last_update': '2024-02-26T12:45:58+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.346942, 50.84563]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '4998d5d5e140b1d08c6a9fc186e979dbca73ddc5',
#    'fields': {'available_bike_stands': 8,
#     'bike_stands': 24,
#     'number': 230,
#     'address': 'BERKENDAEL / BERKENDAAL - AVENUE ALBERT / ALBERTLAAN 134',
#     'name': '230 - BERKENDAEL / BERKENDAAL',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 15,
#     'position': [50.818382, 4.346061],
#     'last_update': '2024-02-26T12:45:14+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.346061, 50.818382]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'd7f232853d00c3ebb85d915dbfa2dab1dbebf0f9',
#    'fields': {'available_bike_stands': 9,
#     'bike_stands': 25,
#     'number': 152,
#     'address': 'PLACE DAILLY / DAILLYPLEIN - PLACE DAILLY / DAILLYPLEIN 24 - 25',
#     'name': '152 - PLACE DAILLY/DAILLYPLEIN',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 16,
#     'position': [50.852389, 4.387373],
#     'last_update': '2024-02-26T12:47:00+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.387373, 50.852389]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '06268ab5d44788e8d64bfffd57eb362894c20e3d',
#    'fields': {'available_bike_stands': 10,
#     'bike_stands': 25,
#     'number': 176,
#     'address': 'COLONEL BOURG/KOLONEL BOURG - RUE COLONEL BOURG/ KOLONEL BOURGSTRAAT 104',
#     'name': '176 - COLONEL BOURG/KOLONEL BOURG',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 15,
#     'position': [50.852356, 4.408635],
#     'last_update': '2024-02-26T12:46:06+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.408635, 50.852356]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '30f64650f0dc443162a433d6dea0b5e45f9400a9',
#    'fields': {'available_bike_stands': 5,
#     'bike_stands': 27,
#     'number': 28,
#     'address': 'CLEMENCEAU - CHEE DE MONS/ BERGENSE STEENWEG 159-161-163',
#     'name': '028 - CLEMENCEAU',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'CLOSED',
#     'available_bikes': 22,
#     'position': [50.842005, 4.3305],
#     'last_update': '2024-02-26T12:45:46+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.3305, 50.842005]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '02845b9dd850f0635aacc3f19d8f4b64f32bed20',
#    'fields': {'available_bike_stands': 16,
#     'bike_stands': 25,
#     'number': 325,
#     'address': 'HANKAR - CHEE DE WAVRE / WAVERSESTEENWEG 1208',
#     'name': '325 - HANKAR',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.821441, 4.406925],
#     'last_update': '2024-02-26T12:45:55+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.406925, 50.821441]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '4bc5a94c53cf77eead4092bb3ce4866b74a61b78',
#    'fields': {'available_bike_stands': 8,
#     'bike_stands': 18,
#     'number': 288,
#     'address': 'HOUZEAU - AVENUE HOUZEAU 21 / HOUZEAULAAN 21',
#     'name': '288 - HOUZEAU',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 10,
#     'position': [50.80351, 4.3589],
#     'last_update': '2024-02-26T12:45:59+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.3589, 50.80351]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '6ac2d226ac3781e0ebfe9ec81de42a2b90c61ce7',
#    'fields': {'available_bike_stands': 16,
#     'bike_stands': 25,
#     'number': 324,
#     'address': 'THOMAS BALIS - CHEE DE WAVRE 1395 à 1403 / WAVERSESTEENWEG 1395 TOT 1403',
#     'name': '324 - THOMAS BALIS',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.819641, 4.412926],
#     'last_update': '2024-02-26T12:46:58+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.412926, 50.819641]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'b198e05fdf3750da2523c3ca098014cfd9f720f0',
#    'fields': {'available_bike_stands': 18,
#     'bike_stands': 42,
#     'number': 141,
#     'address': 'GARE DU NORD/NOORDSTATION - PLACE SIMON BOLIVAR/ SIMON BOLIVARLAAN',
#     'name': '141 - GARE DU NORD/NOORDSTATION',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 22,
#     'position': [50.8607543151327, 4.358885700202],
#     'last_update': '2024-02-26T12:46:17+00:00'},
#    'geometry': {'type': 'Point',
#     'coordinates': [4.358885700202, 50.8607543151327]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '9b3612490f87bb75a71317fd89096297470aa074',
#    'fields': {'available_bike_stands': 7,
#     'bike_stands': 21,
#     'number': 3,
#     'address': 'PORTE DE FLANDRE/VLAAMSEPOORT - BLD DE NIEUPORT/NIEUWPOORTLAAN 1',
#     'name': '003 - PORTE DE FLANDRE / VLAAMSEPOORT',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 12,
#     'position': [50.853203, 4.341823],
#     'last_update': '2024-02-26T12:45:59+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.341823, 50.853203]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '4f04133e18b3d2974e14a85683746421bde35e19',
#    'fields': {'available_bike_stands': 6,
#     'bike_stands': 20,
#     'number': 331,
#     'address': 'GEORGES HENRI - AV GEORGES HENRI',
#     'name': '331 - GEORGES HENRI',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.842319, 4.406295],
#     'last_update': '2024-02-26T12:46:21+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.406295, 50.842319]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'fd3f54734ca782db7ce240b1ef69f44586226fb5',
#    'fields': {'available_bike_stands': 17,
#     'bike_stands': 22,
#     'number': 326,
#     'address': 'ADEPS - CHEE DE WAVRE / WAVERSESTEENWEG 2057',
#     'name': '326 - ADEPS',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 5,
#     'position': [50.809406, 4.443777],
#     'last_update': '2024-02-26T12:46:51+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.443777, 50.809406]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '145eb11bd908b5351efdf433f341ebfed5bca597',
#    'fields': {'available_bike_stands': 15,
#     'bike_stands': 25,
#     'number': 212,
#     'address': 'THEO LAMBERT - BD THEO LAMBERT (FACE 66) / THEO LAMBERT LAAN (TEGENOVER 66)',
#     'name': '212 - THEO LAMBERT',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 10,
#     'position': [50.82701, 4.292098],
#     'last_update': '2024-02-26T12:45:05+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.292098, 50.82701]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'c2371b3c9f6d51534389171bb139c95c846990fd',
#    'fields': {'available_bike_stands': 12,
#     'bike_stands': 19,
#     'number': 231,
#     'address': 'KERSBEEK - AV KERSBEEK 107 / KERSBEEKLAAN 107',
#     'name': '231 - KERSBEEK',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 7,
#     'position': [50.805801, 4.3194],
#     'last_update': '2024-02-26T12:49:38+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.3194, 50.805801]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '96f74a455b50201ea897e3d82003043dbb6738e9',
#    'fields': {'available_bike_stands': 22,
#     'bike_stands': 30,
#     'number': 122,
#     'address': "GARE D'ETTERBEEK/STATION VAN ETTERBEEK - BOULEVARD GENERAL JACQUES/GENERAAL JACQUESLAAN",
#     'name': "122 - GARE D'ETTERBEEK",
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 8,
#     'position': [50.822207, 4.389325],
#     'last_update': '2024-02-26T12:50:40+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.389325, 50.822207]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'b518f93a4091ecec4f4ffd1feff47152b181753d',
#    'fields': {'available_bike_stands': 12,
#     'bike_stands': 25,
#     'number': 181,
#     'address': 'LOUIS TITZ - AVENUE DE LA CHASSE/ JACHTLAAN 182 - 184',
#     'name': '181 - LOUIS TITZ',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 13,
#     'position': [50.835723, 4.394395],
#     'last_update': '2024-02-26T12:49:12+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.394395, 50.835723]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'd30708e4dd134a031cc666e5dc09411d16840048',
#    'fields': {'available_bike_stands': 11,
#     'bike_stands': 25,
#     'number': 125,
#     'address': 'GEORGES BRUGMANN - PLACE GEORGES BRUGMANN/GEORGES BRUGMANNPLEIN N° 10 - 11',
#     'name': '125 - GEORGES BRUGMANN',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.817392, 4.354105],
#     'last_update': '2024-02-26T12:50:05+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.354105, 50.817392]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '8d7874a4e943ec06405d2e071742735caac75122',
#    'fields': {'available_bike_stands': 9,
#     'bike_stands': 20,
#     'number': 335,
#     'address': 'THIRY - BD DE LA WOLUWE DVT 100',
#     'name': '335 - THIRY',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 11,
#     'position': [50.854231, 4.444034],
#     'last_update': '2024-02-26T12:49:55+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.444034, 50.854231]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'a188e2bd1d7c6c80a36135c96463ff8263dc7e42',
#    'fields': {'available_bike_stands': 16,
#     'bike_stands': 25,
#     'number': 232,
#     'address': 'DOMAINE / DOMEIN - AV DU DOMAINE (FACE 150) / DOMEINELAAN (VOOR 150)',
#     'name': '232 - DOMAINE / DOMEIN',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.810875, 4.329158],
#     'last_update': '2024-02-26T12:50:17+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.329158, 50.810875]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '24cc0b983f4aceeb25365d7a9a310082ce6530b4',
#    'fields': {'available_bike_stands': 14,
#     'bike_stands': 24,
#     'number': 191,
#     'address': 'ARTAN - RUE CLAYS',
#     'name': '191 - ARTAN',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 10,
#     'position': [50.853973, 4.38374],
#     'last_update': '2024-02-26T12:49:35+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.38374, 50.853973]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '8bddf6ddf8d90f7f1ee8bbefe5354aedef865c62',
#    'fields': {'available_bike_stands': 13,
#     'bike_stands': 25,
#     'number': 86,
#     'address': 'MAISON COMMUNALE DE JETTE GEMEENTEHUIS - Chau. de Wemmel / Wemmelsesteenweg 102',
#     'name': '086 - MAISON COMMUNALE DE JETTE GEMEENTEHUIS',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 12,
#     'position': [50.876195, 4.324477],
#     'last_update': '2024-02-26T12:50:17+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.324477, 50.876195]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '137d9f0e0c6b2e1eb80bd95a28340630caf93152',
#    'fields': {'available_bike_stands': 8,
#     'bike_stands': 25,
#     'number': 154,
#     'address': 'PLASKY - SQUARE EUGENE PLASKY (FACE 100) / EUGENE PLASKYSQUARE (TEGENOVER 100)',
#     'name': '154 - PLASKY/PLASKY',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 15,
#     'position': [50.851241, 4.396386],
#     'last_update': '2024-02-26T12:50:19+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.396386, 50.851241]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '958b80968e2b2db6566694ff0fe17da75fbc9083',
#    'fields': {'available_bike_stands': 13,
#     'bike_stands': 25,
#     'number': 208,
#     'address': 'MELBA - AV NELLIE MELBA (FACE 1 a 9) / NELLIE MELBALAAN (TEGENOVER 1 tot 9)',
#     'name': '208 - MELBA',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 12,
#     'position': [50.832565, 4.294311],
#     'last_update': '2024-02-26T12:51:04+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.294311, 50.832565]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '86c606243ff7787f5b28618b9952da9962fcbc98',
#    'fields': {'available_bike_stands': 12,
#     'bike_stands': 20,
#     'number': 238,
#     'address': 'UNION SAINT-GILLOISE / SINT-GILLIS UNIE - CH DE BRUXELLES 366-362 / BRUSSELSESTEENWEG 366-362',
#     'name': '238 - UNION SAINT-GILLOISE / SINT-GILLIS UNIE',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 7,
#     'position': [50.820278, 4.330802],
#     'last_update': '2024-02-26T12:50:38+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.330802, 50.820278]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'bd709909adf723954aa94c2042cee6a695d66dc8',
#    'fields': {'available_bike_stands': 10,
#     'bike_stands': 40,
#     'number': 16,
#     'address': 'LOUISE/LOUIZA - PLACE LOUISE/LOUIZAPLEIN 53',
#     'name': '016 - LOUISE / LOUIZA',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 30,
#     'position': [50.835968, 4.355508],
#     'last_update': '2024-02-26T12:50:45+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.355508, 50.835968]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'b53ba1d9e1a4eb8cbb124b2e9d7a54be6b2a4166',
#    'fields': {'available_bike_stands': 11,
#     'bike_stands': 25,
#     'number': 123,
#     'address': 'BASCULE -  CHAUSSEE DE VLEURGAT (DEVANT 315 - 317) / VLEURGATSESTEENWEG  (N° 315 - 317)',
#     'name': '123 - BASCULE',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.817507, 4.366498],
#     'last_update': '2024-02-26T12:51:03+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.366498, 50.817507]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '0d8f2a8390c4d497d62fe07053eb6d2f62ec7715',
#    'fields': {'available_bike_stands': 10,
#     'bike_stands': 25,
#     'number': 147,
#     'address': "EMILE MAX LYCEE/LYCEUM EMILE MAX - CHAUSSEE D'HAECHT/ HAACHTSESTEENWEG 226 - 230",
#     'name': '147 - EMILE MAX LYCEE/LYCEUM EMILE MAX',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.861874, 4.372146],
#     'last_update': '2024-02-26T12:49:26+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.372146, 50.861874]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '24a11b9f26c5945574222458ce5270db908bc5e2',
#    'fields': {'available_bike_stands': 8,
#     'bike_stands': 20,
#     'number': 47,
#     'address': 'LES QUAIS/KAAIEN - QUAI A LA CHAUX/KALKKAAI 1-2',
#     'name': '047 - LES QUAIS / KAAIEN',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.854714, 4.347151],
#     'last_update': '2024-02-26T12:50:49+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.347151, 50.854714]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '3c1bded9eda4c5a9c32571276bcd2829b4537277',
#    'fields': {'available_bike_stands': 18,
#     'bike_stands': 25,
#     'number': 312,
#     'address': 'CENTRE CULTUREL / CULTUREEL CENTRUM - BD DU SOUVERAIN FACE 282 / VORSTLAAN VOOR 282',
#     'name': '312 - CENTRE CULTUREL / CULTUREEL CENTRUM',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 6,
#     'position': [50.816948, 4.426551],
#     'last_update': '2024-02-26T12:49:21+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.426551, 50.816948]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '28277f5dfe8ff6667e67ac678b04d191826d1260',
#    'fields': {'available_bike_stands': 9,
#     'bike_stands': 25,
#     'number': 239,
#     'address': 'DARWIN - AV. BRUGMANN / BRUGMANNLAAN 139-147',
#     'name': '239 - DARWIN',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.817777, 4.350406],
#     'last_update': '2024-02-26T12:50:31+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.350406, 50.817777]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '0bbcce6be67f7e39d0e994b285d91287440f1a25',
#    'fields': {'available_bike_stands': 14,
#     'bike_stands': 25,
#     'number': 182,
#     'address': 'BOILEAU - BOULEVARD SAINT MICHEL / SINT-MICHIELSLAAN',
#     'name': '182 - BOILEAU',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 11,
#     'position': [50.83168, 4.404769],
#     'last_update': '2024-02-26T12:50:14+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.404769, 50.83168]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '2e8bc98a0f4a10084b5a66a446f816b12c3322cf',
#    'fields': {'available_bike_stands': 13,
#     'bike_stands': 22,
#     'number': 254,
#     'address': 'BASILIQUE / BASILIEK - AV JACQUES SERMON / JACUES SERMONLAAN',
#     'name': '254 - BASILIQUE / BASILIEK',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 7,
#     'position': [50.867393, 4.320344],
#     'last_update': '2024-02-26T12:50:30+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.320344, 50.867393]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '8cf2d384e35a0714e93b8cf08122b59adcde2916',
#    'fields': {'available_bike_stands': 6,
#     'bike_stands': 20,
#     'number': 63,
#     'address': 'JULES CESAR - AVENUE DE TERVUREN DEVANT / TERVURENLAAN VOOR 278',
#     'name': '063 - JULES CESAR',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 14,
#     'position': [50.834705, 4.421643],
#     'last_update': '2024-02-26T12:49:52+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.421643, 50.834705]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '46a38a73982960fbb7555f7c92eabb9f8c8cf9a2',
#    'fields': {'available_bike_stands': 4,
#     'bike_stands': 20,
#     'number': 364,
#     'address': 'DOCKS BRUXSEL - AVENUE JULES VAN PRAETLAAN',
#     'name': '364 - DOCKS BRUXSEL',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 16,
#     'position': [50.879086, 4.374729],
#     'last_update': '2024-02-26T12:49:33+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.374729, 50.879086]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '44c146194949424888b92e3f343a0d6ae23f084f',
#    'fields': {'available_bike_stands': 12,
#     'bike_stands': 25,
#     'number': 15,
#     'address': 'MONTGOMERY - AVENUE DE TERVUREN / TERVURENLAAN 136-138',
#     'name': '015 - MONTGOMERY',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 13,
#     'position': [50.837036, 4.406826],
#     'last_update': '2024-02-26T12:49:24+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.406826, 50.837036]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '5e99d2788d1b84e5afd7c725f578b5d8ad509e44',
#    'fields': {'available_bike_stands': 21,
#     'bike_stands': 44,
#     'number': 179,
#     'address': 'CELTES/KELTEN - AVENUE DE TERVUEREN (FACE AU 17) / TERVURENLAAN (TEGENOVER 17)',
#     'name': '179 - CELTES/KELTEN',
#     'bonus': 'True',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 18,
#     'position': [50.839217, 4.398015],
#     'last_update': '2024-02-26T12:50:24+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.398015, 50.839217]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '5e81b4798ceb2657cf5d9d431f30d200d69444c3',
#    'fields': {'available_bike_stands': 18,
#     'bike_stands': 25,
#     'number': 42,
#     'address': "PORTE DE NINOVE / NINOOFSEPOORT - Pl. de Ninove x Bd de l'Abattoir / Ninoofseplein x Slachthuislaan",
#     'name': '042 - PORTE DE NINOVE / NINOOFSEPOORT',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 7,
#     'position': [50.84851, 4.338064],
#     'last_update': '2024-02-26T12:49:50+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.338064, 50.84851]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'ccadf97e1438ed1abeb0a3fb288a5f766a7206c1',
#    'fields': {'available_bike_stands': 11,
#     'bike_stands': 22,
#     'number': 148,
#     'address': 'GARE MEISER / MEISER STATION - AVENUE ROGIER/ ROGIERLAAN 377 - 379',
#     'name': '148 - GARE MEISER/MEISER STATION',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 10,
#     'position': [50.855629, 4.394807],
#     'last_update': '2024-02-26T12:50:32+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.394807, 50.855629]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'b9adac903756ae7a543c790719f5c3add942a0a4',
#    'fields': {'available_bike_stands': 8,
#     'bike_stands': 20,
#     'number': 327,
#     'address': 'SIBELGA - QUAI DES USINES / WERKHUIZENKAAI 16',
#     'name': '327 - SIBELGA',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 11,
#     'position': [50.874082, 4.362205],
#     'last_update': '2024-02-26T12:49:48+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.362205, 50.874082]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': 'fcb06f8b2e8885c44d5b21b3e51c4568518865b0',
#    'fields': {'available_bike_stands': 16,
#     'bike_stands': 25,
#     'number': 163,
#     'address': 'CHAZAL - AVENUE ERNEST CAMBIER (FACE 7)/ ERNEST CAMBIERLAAN (TEGENOVER 7)',
#     'name': '163 - CHAZAL/CHAZAL',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.859112, 4.39157],
#     'last_update': '2024-02-26T12:50:07+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.39157, 50.859112]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '5e4f5c3b767b2e15827c2686434dcb06db0bee23',
#    'fields': {'available_bike_stands': 10,
#     'bike_stands': 20,
#     'number': 334,
#     'address': 'MARCEL THIRY - AV MARCEL THIRY FACE 23',
#     'name': '334 - MARCEL THIRY',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 9,
#     'position': [50.855593, 4.439625],
#     'last_update': '2024-02-26T12:49:22+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.439625, 50.855593]}},
#   {'datasetid': 'jcdecaux-bike-stations-data-rt',
#    'recordid': '84e810acb99e02b68fab53b026991b46f4e63ba1',
#    'fields': {'available_bike_stands': 6,
#     'bike_stands': 25,
#     'number': 276,
#     'address': 'CROIX DE GUERRES / OORLOGSKRUISEN - AVENUE DES CROIX DE GUERRE / OORLOGSKRUISENLAAN 116',
#     'name': '276 - CROIX DE GUERRES / OORLOGSKRUISEN',
#     'bonus': 'False',
#     'banking': 'False',
#     'contract_name': 'Bruxelles-Capitale',
#     'status': 'OPEN',
#     'available_bikes': 19,
#     'position': [50.889748, 4.380755],
#     'last_update': '2024-02-26T12:50:09+00:00'},
#    'geometry': {'type': 'Point', 'coordinates': [4.380755, 50.889748]}}],
#  'facet_groups': [{'name': 'banking',
#    'facets': [{'name': 'False',
#      'count': 351,
#      'state': 'displayed',
#      'path': 'False'}]},
#   {'name': 'name',
#    'facets': [{'name': '001 - LEOPOLD II',
#      'count': 1,
#      'state': 'displayed',
#      'path': '001 - LEOPOLD II'},
#     {'name': '002 - ELOY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '002 - ELOY'},
#     {'name': '003 - PORTE DE FLANDRE / VLAAMSEPOORT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '003 - PORTE DE FLANDRE / VLAAMSEPOORT'},
#     {'name': '004 - JARDIN AUX FLEURS / BLOEMENHOF',
#      'count': 1,
#      'state': 'displayed',
#      'path': '004 - JARDIN AUX FLEURS / BLOEMENHOF'},
#     {'name': '005 - BOURSE / BEURS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '005 - BOURSE / BEURS'},
#     {'name': '006 - GARE CENTRALE / CENTRAAL STATION',
#      'count': 1,
#      'state': 'displayed',
#      'path': '006 - GARE CENTRALE / CENTRAAL STATION'},
#     {'name': '007 - PARC / PARK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '007 - PARC / PARK'},
#     {'name': '008 - ARTS-LOI / KUNST-WET',
#      'count': 1,
#      'state': 'displayed',
#      'path': '008 - ARTS-LOI / KUNST-WET'},
#     {'name': '009 - ANNEESSENS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '009 - ANNEESSENS'},
#     {'name': '010 - CHAPELLE / KAPEL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '010 - CHAPELLE / KAPEL'},
#     {'name': '011 - SABLON / ZAVEL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '011 - SABLON / ZAVEL'},
#     {'name': '012 - TRONE / TROON',
#      'count': 1,
#      'state': 'displayed',
#      'path': '012 - TRONE / TROON'},
#     {'name': '013 - LEMONNIER',
#      'count': 1,
#      'state': 'displayed',
#      'path': '013 - LEMONNIER'},
#     {'name': '014 - PORTE DE NAMUR / NAAMSEPOORT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '014 - PORTE DE NAMUR / NAAMSEPOORT'},
#     {'name': '015 - MONTGOMERY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '015 - MONTGOMERY'},
#     {'name': '016 - LOUISE / LOUIZA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '016 - LOUISE / LOUIZA'},
#     {'name': '017 - COMTE DE FLANDRE / GRAAF VAN VLAANDEREN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '017 - COMTE DE FLANDRE / GRAAF VAN VLAANDEREN'},
#     {'name': '018 - GUTENBERG',
#      'count': 1,
#      'state': 'displayed',
#      'path': '018 - GUTENBERG'},
#     {'name': '019 - PLACE MORICHAR / MORICHARPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '019 - PLACE MORICHAR / MORICHARPLEIN'},
#     {'name': '020 - PALAIS ROYAL / KONINKLIJK PALEIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '020 - PALAIS ROYAL / KONINKLIJK PALEIS'},
#     {'name': '021 - DE BROUCKERE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '021 - DE BROUCKERE'},
#     {'name': '022 - JACQMAIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '022 - JACQMAIN'},
#     {'name': '023 - AGORA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '023 - AGORA'},
#     {'name': '024 - ROGIER',
#      'count': 1,
#      'state': 'displayed',
#      'path': '024 - ROGIER'},
#     {'name': "025 - PORTE D'ANDERLECHT",
#      'count': 1,
#      'state': 'displayed',
#      'path': "025 - PORTE D'ANDERLECHT"},
#     {'name': '026 - VAN LINT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '026 - VAN LINT'},
#     {'name': '027 - SQUARE ALBERT I / ALBERT I SQUARE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '027 - SQUARE ALBERT I / ALBERT I SQUARE'},
#     {'name': '028 - CLEMENCEAU',
#      'count': 1,
#      'state': 'displayed',
#      'path': '028 - CLEMENCEAU'},
#     {'name': '030 - LAEKEN / LAKEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '030 - LAEKEN / LAKEN'},
#     {'name': '031 - MUSEE DE LA BD / STRIPMUSEUM',
#      'count': 1,
#      'state': 'displayed',
#      'path': '031 - MUSEE DE LA BD / STRIPMUSEUM'},
#     {'name': '032 - DANSAERT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '032 - DANSAERT'},
#     {'name': '033 - MORT SUBITE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '033 - MORT SUBITE'},
#     {'name': '034 - FONTAINAS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '034 - FONTAINAS'},
#     {'name': '036 - PLACE ST-JEAN / SINT-JANSPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '036 - PLACE ST-JEAN / SINT-JANSPLEIN'},
#     {'name': '037 - POELAERT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '037 - POELAERT'},
#     {'name': '038 - JEU DE BALLE / VOSSENPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '038 - JEU DE BALLE / VOSSENPLEIN'},
#     {'name': '039 - HOTEL DES MONNAIES / MUNTHOTEL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '039 - HOTEL DES MONNAIES / MUNTHOTEL'},
#     {'name': '040 - PORTE DE HAL / HALLEPOORT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '040 - PORTE DE HAL / HALLEPOORT'},
#     {'name': '041 - SAINT-ROCH / SINT-ROCHUS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '041 - SAINT-ROCH / SINT-ROCHUS'},
#     {'name': '042 - PORTE DE NINOVE / NINOOFSEPOORT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '042 - PORTE DE NINOVE / NINOOFSEPOORT'},
#     {'name': '043 - JOSEPH II / JOZEF II',
#      'count': 1,
#      'state': 'displayed',
#      'path': '043 - JOSEPH II / JOZEF II'},
#     {'name': '044 - CHARLEMAGNE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '044 - CHARLEMAGNE'},
#     {'name': '045 - STEPHANIE / STEFANIA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '045 - STEPHANIE / STEFANIA'},
#     {'name': '046 - ALBERTINE / ALBERTINA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '046 - ALBERTINE / ALBERTINA'},
#     {'name': '047 - LES QUAIS / KAAIEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '047 - LES QUAIS / KAAIEN'},
#     {'name': '048 - CONGRES',
#      'count': 1,
#      'state': 'displayed',
#      'path': '048 - CONGRES'},
#     {'name': '049 - WILLEBROECK / WILLEBROEK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '049 - WILLEBROECK / WILLEBROEK'},
#     {'name': '050 - RIBAUCOURT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '050 - RIBAUCOURT'},
#     {'name': '051 - MIDI FONSNY / ZUID FONSNY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '051 - MIDI FONSNY / ZUID FONSNY'},
#     {'name': '052 - SAINCTELETTE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '052 - SAINCTELETTE'},
#     {'name': '053 - GARE DU MIDI / ZUIDSTATION',
#      'count': 1,
#      'state': 'displayed',
#      'path': '053 - GARE DU MIDI / ZUIDSTATION'},
#     {'name': '054 - TOUR ET TAXIS / THURN & TAXIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '054 - TOUR ET TAXIS / THURN & TAXIS'},
#     {'name': '055 - BOTANIQUE / KRUIDTUIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '055 - BOTANIQUE / KRUIDTUIN'},
#     {'name': '056 - ARCHIMEDE / ARCHIMEDES',
#      'count': 1,
#      'state': 'displayed',
#      'path': '056 - ARCHIMEDE / ARCHIMEDES'},
#     {'name': '057 - MADOU',
#      'count': 1,
#      'state': 'displayed',
#      'path': '057 - MADOU'},
#     {'name': '058 - GARE DU NORD / NOORDSTATION',
#      'count': 1,
#      'state': 'displayed',
#      'path': '058 - GARE DU NORD / NOORDSTATION'},
#     {'name': '059 - PLACE ST-JOSSE / ST-JOOSTPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '059 - PLACE ST-JOSSE / ST-JOOSTPLEIN'},
#     {'name': '060 - SAINT-LAZARE / SINT-LAZARUS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '060 - SAINT-LAZARE / SINT-LAZARUS'},
#     {'name': '061 - MAELBEEK / MAALBEEK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '061 - MAELBEEK / MAALBEEK'},
#     {'name': '062 - CORTENBERGH / KORTENBERG',
#      'count': 1,
#      'state': 'displayed',
#      'path': '062 - CORTENBERGH / KORTENBERG'},
#     {'name': '063 - JULES CESAR',
#      'count': 1,
#      'state': 'displayed',
#      'path': '063 - JULES CESAR'},
#     {'name': '064 - VETERINAIRES',
#      'count': 1,
#      'state': 'displayed',
#      'path': '064 - VETERINAIRES'},
#     {'name': '065 - PARVIS DE ST-GILLES / ST-GILLISVOORPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '065 - PARVIS DE ST-GILLES / ST-GILLISVOORPLEIN'},
#     {'name': '066 - SCHUMAN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '066 - SCHUMAN'},
#     {'name': '067 - PARC CINQUANTENAIRE / JUBELPARK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '067 - PARC CINQUANTENAIRE / JUBELPARK'},
#     {'name': '068 - JEAN REY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '068 - JEAN REY'},
#     {'name': '069 - LESBROUSSART',
#      'count': 1,
#      'state': 'displayed',
#      'path': '069 - LESBROUSSART'},
#     {'name': '070 - AURORE / DAGERAAD',
#      'count': 1,
#      'state': 'displayed',
#      'path': '070 - AURORE / DAGERAAD'},
#     {'name': '071 - LEGRAND',
#      'count': 1,
#      'state': 'displayed',
#      'path': '071 - LEGRAND'},
#     {'name': '072 - ULB SOLBOSCH / VUB  SOLBOSCH',
#      'count': 1,
#      'state': 'displayed',
#      'path': '072 - ULB SOLBOSCH / VUB  SOLBOSCH'},
#     {'name': '073 - VLEURGAT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '073 - VLEURGAT'},
#     {'name': '074 - PLACE LOIX / LOIXPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '074 - PLACE LOIX / LOIXPLEIN'},
#     {'name': '075 - GENERAL BARON / GENERAAL BARON',
#      'count': 1,
#      'state': 'displayed',
#      'path': '075 - GENERAL BARON / GENERAAL BARON'},
#     {'name': '076 - PLACE VAN MEENEN / VAN MEENENPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '076 - PLACE VAN MEENEN / VAN MEENENPLEIN'},
#     {'name': '077 - PAUL JANSON',
#      'count': 1,
#      'state': 'displayed',
#      'path': '077 - PAUL JANSON'},
#     {'name': '078 - DUC PETIAUX',
#      'count': 1,
#      'state': 'displayed',
#      'path': '078 - DUC PETIAUX'},
#     {'name': '079 - LOI / WET',
#      'count': 1,
#      'state': 'displayed',
#      'path': '079 - LOI / WET'},
#     {'name': '080 - CERES',
#      'count': 1,
#      'state': 'displayed',
#      'path': '080 - CERES'},
#     {'name': '081 - PONT BOCKSTAEL / BRUG BOCKSTAEL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '081 - PONT BOCKSTAEL / BRUG BOCKSTAEL'},
#     {'name': '082 - PANNENHUIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '082 - PANNENHUIS'},
#     {'name': '083 - SIMONIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '083 - SIMONIS'},
#     {'name': '084 - SAINTE-ANNE / SINT-ANNA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '084 - SAINTE-ANNE / SINT-ANNA'},
#     {'name': '085 - ETANGS NOIRS / ZWARTE VIJVERS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '085 - ETANGS NOIRS / ZWARTE VIJVERS'},
#     {'name': '086 - MAISON COMMUNALE DE JETTE GEMEENTEHUIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '086 - MAISON COMMUNALE DE JETTE GEMEENTEHUIS'},
#     {'name': '087 - MIROIR / SPIEGEL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '087 - MIROIR / SPIEGEL'},
#     {'name': '088 - WOESTE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '088 - WOESTE'},
#     {'name': '089 - ATHENEE DE JETTE / ATHENEUM VAN JETTE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '089 - ATHENEE DE JETTE / ATHENEUM VAN JETTE'},
#     {'name': '090 - BROUSTIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '090 - BROUSTIN'},
#     {'name': '091 - BELGICA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '091 - BELGICA'},
#     {'name': '092 - LENOIR',
#      'count': 1,
#      'state': 'displayed',
#      'path': '092 - LENOIR'},
#     {'name': '093 - CLOVIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '093 - CLOVIS'},
#     {'name': '094 - DUCHESSE DE BRABANT / HERTOGIN VAN BRABANT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '094 - DUCHESSE DE BRABANT / HERTOGIN VAN BRABANT'},
#     {'name': '095 - PLACE BOCKSTAEL / BOCKSTAELPLAATS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '095 - PLACE BOCKSTAEL / BOCKSTAELPLAATS'},
#     {'name': '096 - HOTEL PRESIDENT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '096 - HOTEL PRESIDENT'},
#     {'name': '097 - KARREVELD',
#      'count': 1,
#      'state': 'displayed',
#      'path': '097 - KARREVELD'},
#     {'name': '098 - CIMETIERE / KERKHOF',
#      'count': 1,
#      'state': 'displayed',
#      'path': '098 - CIMETIERE / KERKHOF'},
#     {'name': '099 - JUBILE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '099 - JUBILE'},
#     {'name': '100 - GARE DE LUXEMBOURG / LUXEMBURGSTATION',
#      'count': 1,
#      'state': 'displayed',
#      'path': '100 - GARE DE LUXEMBOURG / LUXEMBURGSTATION'},
#     {'name': '101 - ZELLIK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '101 - ZELLIK'},
#     {'name': '102 - MUSEUM/MUSEUM',
#      'count': 1,
#      'state': 'displayed',
#      'path': '102 - MUSEUM/MUSEUM'},
#     {'name': '105 - DE HENNIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '105 - DE HENNIN'},
#     {'name': '106 - GERMOIR/MOUTERIJ',
#      'count': 1,
#      'state': 'displayed',
#      'path': '106 - GERMOIR/MOUTERIJ'},
#     {'name': '107 - DEFACQZ',
#      'count': 1,
#      'state': 'displayed',
#      'path': '107 - DEFACQZ'},
#     {'name': '108 - FLAGEY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '108 - FLAGEY'},
#     {'name': '109 - CHATELAIN/KASTELEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '109 - CHATELAIN/KASTELEIN'},
#     {'name': '110 - RODIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '110 - RODIN'},
#     {'name': '111 - ETANGS MELLAERTS VIJVERS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '111 - ETANGS MELLAERTS VIJVERS'},
#     {'name': '112 - PAGE/EDELKNAAP',
#      'count': 1,
#      'state': 'displayed',
#      'path': '112 - PAGE/EDELKNAAP'},
#     {'name': '113 - ABBAYE DE LA CAMBRE / ABDIJ TER KAMEREN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '113 - ABBAYE DE LA CAMBRE / ABDIJ TER KAMEREN'},
#     {'name': '114 - SAISONS/JAARGETIJDEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '114 - SAISONS/JAARGETIJDEN'},
#     {'name': '115 - PETITE SUISSE/KLEIN ZWITSERLAND',
#      'count': 1,
#      'state': 'displayed',
#      'path': '115 - PETITE SUISSE/KLEIN ZWITSERLAND'},
#     {'name': '116 - ULB PLAINE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '116 - ULB PLAINE'},
#     {'name': "117 - CIMETIERE D'IXELLES/BEGRAAFPLAATS VAN ELSENE",
#      'count': 1,
#      'state': 'displayed',
#      'path': "117 - CIMETIERE D'IXELLES/BEGRAAFPLAATS VAN ELSENE"},
#     {'name': '118 - SCHWEITZER',
#      'count': 1,
#      'state': 'displayed',
#      'path': '118 - SCHWEITZER'},
#     {'name': '119 - PAQUOT/PACQUOT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '119 - PAQUOT/PACQUOT'},
#     {'name': '120 - BLYCKAERTS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '120 - BLYCKAERTS'},
#     {'name': '121 - ETANGS / VIJVERS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '121 - ETANGS / VIJVERS'},
#     {'name': "122 - GARE D'ETTERBEEK",
#      'count': 1,
#      'state': 'displayed',
#      'path': "122 - GARE D'ETTERBEEK"},
#     {'name': '123 - BASCULE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '123 - BASCULE'},
#     {'name': '124 - CHARLES GRAUX',
#      'count': 1,
#      'state': 'displayed',
#      'path': '124 - CHARLES GRAUX'},
#     {'name': '125 - GEORGES BRUGMANN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '125 - GEORGES BRUGMANN'},
#     {'name': '126 - FABRY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '126 - FABRY'},
#     {'name': '127 - GRAY/GRAY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '127 - GRAY/GRAY'},
#     {'name': '128 - MUSEE DU TRAM',
#      'count': 1,
#      'state': 'displayed',
#      'path': '128 - MUSEE DU TRAM'},
#     {'name': '130 - ROND POINT DU SOUVERAIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '130 - ROND POINT DU SOUVERAIN'},
#     {'name': '131 - JARDIN MASSART',
#      'count': 1,
#      'state': 'displayed',
#      'path': '131 - JARDIN MASSART'},
#     {'name': '132 - DEUX CHAUSSEES',
#      'count': 1,
#      'state': 'displayed',
#      'path': '132 - DEUX CHAUSSEES'},
#     {'name': '133 - CHÂTEAU/KASTEEL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '133 - CHÂTEAU/KASTEEL'},
#     {'name': '134 - BASTOGNE/BASTENAKEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '134 - BASTOGNE/BASTENAKEN'},
#     {'name': '135 - PARC LACROIX/LACROIX PARK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '135 - PARC LACROIX/LACROIX PARK'},
#     {'name': '136 - PAVILLON/PAVILJOEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '136 - PAVILLON/PAVILJOEN'},
#     {'name': '137 - MAISON COMMUNALE DE SCHAERBEEK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '137 - MAISON COMMUNALE DE SCHAERBEEK'},
#     {'name': '138 - HOUFFALIZE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '138 - HOUFFALIZE'},
#     {'name': '139 - LIEDTS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '139 - LIEDTS'},
#     {'name': '140 - AZALEES/AZALEA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '140 - AZALEES/AZALEA'},
#     {'name': '141 - GARE DU NORD/NOORDSTATION',
#      'count': 1,
#      'state': 'displayed',
#      'path': '141 - GARE DU NORD/NOORDSTATION'},
#     {'name': '142 - BIENFAITEURS/WELDOENERS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '142 - BIENFAITEURS/WELDOENERS'},
#     {'name': '143 - RTL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '143 - RTL'},
#     {'name': '144 - SAINTE-MARIE/SINTE-MARIA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '144 - SAINTE-MARIE/SINTE-MARIA'},
#     {'name': '145 - COTEAUX/WIJNHEUVELEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '145 - COTEAUX/WIJNHEUVELEN'},
#     {'name': '146 - LEOPOLD III/LEOPOLD III',
#      'count': 1,
#      'state': 'displayed',
#      'path': '146 - LEOPOLD III/LEOPOLD III'},
#     {'name': '147 - EMILE MAX LYCEE/LYCEUM EMILE MAX',
#      'count': 1,
#      'state': 'displayed',
#      'path': '147 - EMILE MAX LYCEE/LYCEUM EMILE MAX'},
#     {'name': '148 - GARE MEISER/MEISER STATION',
#      'count': 1,
#      'state': 'displayed',
#      'path': '148 - GARE MEISER/MEISER STATION'},
#     {'name': '149 - JULES LEBRUN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '149 - JULES LEBRUN'},
#     {'name': '150 - MEISER/MEISER',
#      'count': 1,
#      'state': 'displayed',
#      'path': '150 - MEISER/MEISER'},
#     {'name': '151 - LOUVAIN 488-494/LEUVEN 488-494',
#      'count': 1,
#      'state': 'displayed',
#      'path': '151 - LOUVAIN 488-494/LEUVEN 488-494'},
#     {'name': '152 - PLACE DAILLY/DAILLYPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '152 - PLACE DAILLY/DAILLYPLEIN'},
#     {'name': '153 - SQUARE ARMAND STEURS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '153 - SQUARE ARMAND STEURS'},
#     {'name': '154 - PLASKY/PLASKY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '154 - PLASKY/PLASKY'},
#     {'name': '155 - LES MARRONNIERS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '155 - LES MARRONNIERS'},
#     {'name': '156 - JAMBLINE DE MEUX/JAMBLINNE DE MEUX',
#      'count': 1,
#      'state': 'displayed',
#      'path': '156 - JAMBLINE DE MEUX/JAMBLINNE DE MEUX'},
#     {'name': '157 - HELIOTROPES/HELIOTROPEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '157 - HELIOTROPES/HELIOTROPEN'},
#     {'name': '158 - VAN YSENDIJCK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '158 - VAN YSENDIJCK'},
#     {'name': '159 - MASUI',
#      'count': 1,
#      'state': 'displayed',
#      'path': '159 - MASUI'},
#     {'name': '160 - ELISA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '160 - ELISA'},
#     {'name': '161 - DEMOLDER',
#      'count': 1,
#      'state': 'displayed',
#      'path': '161 - DEMOLDER'},
#     {'name': '163 - CHAZAL/CHAZAL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '163 - CHAZAL/CHAZAL'},
#     {'name': '164 - KENNIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '164 - KENNIS'},
#     {'name': '165 - CIMETIERE DE JETTE / KERKHOF JETTE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '165 - CIMETIERE DE JETTE / KERKHOF JETTE'},
#     {'name': '166 - GC ESSEGEM',
#      'count': 1,
#      'state': 'displayed',
#      'path': '166 - GC ESSEGEM'},
#     {'name': '167 - CHARLES V/KAREL V',
#      'count': 1,
#      'state': 'displayed',
#      'path': '167 - CHARLES V/KAREL V'},
#     {'name': '168 - HOPITAL FRANÇAIS/FRANS HOSPITAAL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '168 - HOPITAL FRANÇAIS/FRANS HOSPITAAL'},
#     {'name': '169 - GEORGES EEKHOUD',
#      'count': 1,
#      'state': 'displayed',
#      'path': '169 - GEORGES EEKHOUD'},
#     {'name': '170 - RIGA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '170 - RIGA'},
#     {'name': '171 - PISCINE LOUIS NAMECHE ZWEMBAD',
#      'count': 1,
#      'state': 'displayed',
#      'path': '171 - PISCINE LOUIS NAMECHE ZWEMBAD'},
#     {'name': '172 - AEROPOLIS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '172 - AEROPOLIS'},
#     {'name': '173 - BICHON',
#      'count': 1,
#      'state': 'displayed',
#      'path': '173 - BICHON'},
#     {'name': '174 - MENNEKENS/MENNEKENS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '174 - MENNEKENS/MENNEKENS'},
#     {'name': '175 - BEEKKANT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '175 - BEEKKANT'},
#     {'name': '176 - COLONEL BOURG/KOLONEL BOURG',
#      'count': 1,
#      'state': 'displayed',
#      'path': '176 - COLONEL BOURG/KOLONEL BOURG'},
#     {'name': '177 - CHASSEURS ARDENNAIS/ARDENSE JAGERS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '177 - CHASSEURS ARDENNAIS/ARDENSE JAGERS'},
#     {'name': '178 - DIAMANT/DIAMANT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '178 - DIAMANT/DIAMANT'},
#     {'name': '179 - CELTES/KELTEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '179 - CELTES/KELTEN'},
#     {'name': '180 - JOURDAN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '180 - JOURDAN'},
#     {'name': '181 - LOUIS TITZ',
#      'count': 1,
#      'state': 'displayed',
#      'path': '181 - LOUIS TITZ'},
#     {'name': '182 - BOILEAU',
#      'count': 1,
#      'state': 'displayed',
#      'path': '182 - BOILEAU'},
#     {'name': '183 - LA CHASSE/JACHT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '183 - LA CHASSE/JACHT'},
#     {'name': '184 - PHILIPPE BAUCQ',
#      'count': 1,
#      'state': 'displayed',
#      'path': '184 - PHILIPPE BAUCQ'},
#     {'name': '185 - PERE DE DEKEN/PATER DE DEKEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '185 - PERE DE DEKEN/PATER DE DEKEN'},
#     {'name': '186 - GENOT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '186 - GENOT'},
#     {'name': '187 - ARSENAL/ARSENAAL',
#      'count': 1,
#      'state': 'displayed',
#      'path': '187 - ARSENAL/ARSENAAL'},
#     {'name': '188 - OSSEGHEM',
#      'count': 1,
#      'state': 'displayed',
#      'path': '188 - OSSEGHEM'},
#     {'name': '189 - PLACE VAN MEYEL/VAN MEYELPLEIN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '189 - PLACE VAN MEYEL/VAN MEYELPLEIN'},
#     {'name': '190 - TERDELT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '190 - TERDELT'},
#     {'name': '191 - ARTAN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '191 - ARTAN'},
#     {'name': '192 - AUBERGE DE JEUNESSE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '192 - AUBERGE DE JEUNESSE'},
#     {'name': "193 - GARE DE L'OUEST",
#      'count': 1,
#      'state': 'displayed',
#      'path': "193 - GARE DE L'OUEST"},
#     {'name': '194 - STUYVENBERG',
#      'count': 1,
#      'state': 'displayed',
#      'path': '194 - STUYVENBERG'},
#     {'name': '196 - PRINCE DE LIEGE / PRINS VAN LUIK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '196 - PRINCE DE LIEGE / PRINS VAN LUIK'},
#     {'name': '197 - DE SMET',
#      'count': 1,
#      'state': 'displayed',
#      'path': '197 - DE SMET'},
#     {'name': '198 - SCHEUT',
#      'count': 1,
#      'state': 'displayed',
#      'path': '198 - SCHEUT'},
#     {'name': '199 - HENRI REY',
#      'count': 1,
#      'state': 'displayed',
#      'path': '199 - HENRI REY'},
#     {'name': '200 - VETERANS COLONIAUX / KOLONIALE VETERANEN',
#      'count': 1,
#      'state': 'displayed',
#      'path': '200 - VETERANS COLONIAUX / KOLONIALE VETERANEN'},
#     {'name': '201 - PETERBOS',
#      'count': 1,
#      'state': 'displayed',
#      'path': '201 - PETERBOS'},
#     {'name': '202 - AUMALE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '202 - AUMALE'},
#     {'name': '203 - DEMOSTHENE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '203 - DEMOSTHENE'},
#     {'name': '205 - DE LINDE',
#      'count': 1,
#      'state': 'displayed',
#      'path': '205 - DE LINDE'},
#     {'name': '206 - SAINT-GUIDON / SINT GUIDO',
#      'count': 1,
#      'state': 'displayed',
#      'path': '206 - SAINT-GUIDON / SINT GUIDO'},
#     {'name': '207 - BIESTEBROECK / BIESTEBROEK',
#      'count': 1,
#      'state': 'displayed',
#      'path': '207 - BIESTEBROECK / BIESTEBROEK'},
#     {'name': '208 - MELBA',
#      'count': 1,
#      'state': 'displayed',
#      'path': '208 - MELBA'}]},
#   {'name': 'bonus',
#    'facets': [{'name': 'False',
#      'count': 293,
#      'state': 'displayed',
#      'path': 'False'},
#     {'name': 'True', 'count': 58, 'state': 'displayed', 'path': 'True'}]},
#   {'name': 'status',
#    'facets': [{'name': 'OPEN',
#      'count': 345,
#      'state': 'displayed',
#      'path': 'OPEN'},
#     {'name': 'CLOSED', 'count': 6, 'state': 'displayed', 'path': 'CLOSED'}]},
#   {'name': 'contract_name',
#    'facets': [{'name': 'Bruxelles-Capitale',
#      'count': 351,
#      'state': 'refined',
#      'path': 'Bruxelles-Capitale'}]}]}

# %% [markdown]
# This is a pretty intricate data structure with dictionaries inside lists inside dictionaries. We can visualize it slightly better by re-encoding it in JSON with indentation.

# %%
import json
print(json.dumps(data, indent=4)) # make the output visually more readable
# Out:
# {
#     "nhits": 351,
#     "parameters": {
#         "dataset": "jcdecaux-bike-stations-data-rt",
#         "rows": 50,
#         "start": 0,
#         "facet": [
#             "banking",
#             "name",
#             "bonus",
#             "status",
#             "contract_name"
#         ],
#         "format": "json",
#         "timezone": "UTC"
#     },
#     "records": [
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "6e8b2f6a144a66d65da8d2974bd1a4db0eee4841",
#             "fields": {
#                 "available_bike_stands": 12,
#                 "bike_stands": 25,
#                 "number": 305,
#                 "address": "PETER BENOIT - PLACE PETER BENOIT PLAATS 2-4",
#                 "name": "305 - PETER BENOIT",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 12,
#                 "position": [
#                     50.895592,
#                     4.387965
#                 ],
#                 "last_update": "2024-02-26T12:45:24+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.387965,
#                     50.895592
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "39042b9903ec9a87d9fd670c5999fb52ad8d9e6d",
#             "fields": {
#                 "available_bike_stands": 11,
#                 "bike_stands": 25,
#                 "number": 200,
#                 "address": "VETERANS COLONIAUX / KOLONIALE VETERANEN - BD JULES GRAINDOR / JULES GRAINDORLAAN",
#                 "name": "200 - VETERANS COLONIAUX / KOLONIALE VETERANEN",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.843967,
#                     4.313537
#                 ],
#                 "last_update": "2024-02-26T12:46:03+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.313537,
#                     50.843967
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "f6039901b8d09af2397b1edf8f6c805fa99be5e4",
#             "fields": {
#                 "available_bike_stands": 14,
#                 "bike_stands": 25,
#                 "number": 43,
#                 "address": "JOSEPH II/JOZEF II - RUE JOSEPH II/JOZEF II-STRAAT",
#                 "name": "043 - JOSEPH II / JOZEF II",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 11,
#                 "position": [
#                     50.845256,
#                     4.374501
#                 ],
#                 "last_update": "2024-02-26T12:46:42+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.374501,
#                     50.845256
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "89468bd2064d390b18663917ff6ec2aef6318f05",
#             "fields": {
#                 "available_bike_stands": 9,
#                 "bike_stands": 25,
#                 "number": 271,
#                 "address": "DUBOIS - BD EMILE MACHTENS/LAAN 102-104",
#                 "name": "271 - DUBOIS",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 15,
#                 "position": [
#                     50.851158,
#                     4.309591
#                 ],
#                 "last_update": "2024-02-26T12:46:37+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.309591,
#                     50.851158
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "fdbf237799778416d27a384011b8e3844e61eff8",
#             "fields": {
#                 "available_bike_stands": 19,
#                 "bike_stands": 25,
#                 "number": 131,
#                 "address": "JARDIN MASSART - AV HERMANN DEBROUXLAAN",
#                 "name": "131 - JARDIN MASSART",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 5,
#                 "position": [
#                     50.81329,
#                     4.434751
#                 ],
#                 "last_update": "2024-02-26T12:46:42+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.434751,
#                     50.81329
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "614111dc8bb4d50ca6cbbd9fe20f7d014cbaee80",
#             "fields": {
#                 "available_bike_stands": 21,
#                 "bike_stands": 30,
#                 "number": 214,
#                 "address": "CAMPUS CERIA / CAMPUS VAN CERIA - AV EMILE GRYSON (FACE 6 a 10) / EMILE GRYSONLAAN (TEGENOVER 6 tot 10)",
#                 "name": "214 - CAMPUS CERIA / CAMPUS VAN CERIA",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 9,
#                 "position": [
#                     50.816002,
#                     4.295121
#                 ],
#                 "last_update": "2024-02-26T12:46:46+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.295121,
#                     50.816002
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "ba8d1161f59cd55b73aef06c2a8cfe5bcdaa9531",
#             "fields": {
#                 "available_bike_stands": 12,
#                 "bike_stands": 20,
#                 "number": 343,
#                 "address": "VANDENDRIESCH - RUE J-B VANDENDRIESCH 22-24",
#                 "name": "343 - VANDENDRIESCH",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 8,
#                 "position": [
#                     50.861788,
#                     4.292913
#                 ],
#                 "last_update": "2024-02-26T12:45:51+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.292913,
#                     50.861788
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "92ca851251195416b0f7f203cd8a19214e4a55ca",
#             "fields": {
#                 "available_bike_stands": 16,
#                 "bike_stands": 25,
#                 "number": 207,
#                 "address": "BIESTEBROECK / BIESTEBROEK - CHEE DE MONS (FACE AU 518-526) / BERGENSESTEENWEG (TEGENOVER 518-526)",
#                 "name": "207 - BIESTEBROECK / BIESTEBROEK",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 8,
#                 "position": [
#                     50.833424,
#                     4.313378
#                 ],
#                 "last_update": "2024-02-26T12:46:36+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.313378,
#                     50.833424
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "0e567ef66cc50a463700c462cd3673a903904497",
#             "fields": {
#                 "available_bike_stands": 7,
#                 "bike_stands": 35,
#                 "number": 34,
#                 "address": "FONTAINAS - BLD ANSPACH N\u00b0180 A 192/ANSPACHLAAN N\u00b0180 TOT 192",
#                 "name": "034 - FONTAINAS",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 28,
#                 "position": [
#                     50.84563,
#                     4.346942
#                 ],
#                 "last_update": "2024-02-26T12:45:58+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.346942,
#                     50.84563
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "4998d5d5e140b1d08c6a9fc186e979dbca73ddc5",
#             "fields": {
#                 "available_bike_stands": 8,
#                 "bike_stands": 24,
#                 "number": 230,
#                 "address": "BERKENDAEL / BERKENDAAL - AVENUE ALBERT / ALBERTLAAN 134",
#                 "name": "230 - BERKENDAEL / BERKENDAAL",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 15,
#                 "position": [
#                     50.818382,
#                     4.346061
#                 ],
#                 "last_update": "2024-02-26T12:45:14+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.346061,
#                     50.818382
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "d7f232853d00c3ebb85d915dbfa2dab1dbebf0f9",
#             "fields": {
#                 "available_bike_stands": 9,
#                 "bike_stands": 25,
#                 "number": 152,
#                 "address": "PLACE DAILLY / DAILLYPLEIN - PLACE DAILLY / DAILLYPLEIN 24 - 25",
#                 "name": "152 - PLACE DAILLY/DAILLYPLEIN",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 16,
#                 "position": [
#                     50.852389,
#                     4.387373
#                 ],
#                 "last_update": "2024-02-26T12:47:00+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.387373,
#                     50.852389
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "06268ab5d44788e8d64bfffd57eb362894c20e3d",
#             "fields": {
#                 "available_bike_stands": 10,
#                 "bike_stands": 25,
#                 "number": 176,
#                 "address": "COLONEL BOURG/KOLONEL BOURG - RUE COLONEL BOURG/ KOLONEL BOURGSTRAAT 104",
#                 "name": "176 - COLONEL BOURG/KOLONEL BOURG",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 15,
#                 "position": [
#                     50.852356,
#                     4.408635
#                 ],
#                 "last_update": "2024-02-26T12:46:06+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.408635,
#                     50.852356
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "30f64650f0dc443162a433d6dea0b5e45f9400a9",
#             "fields": {
#                 "available_bike_stands": 5,
#                 "bike_stands": 27,
#                 "number": 28,
#                 "address": "CLEMENCEAU - CHEE DE MONS/ BERGENSE STEENWEG 159-161-163",
#                 "name": "028 - CLEMENCEAU",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "CLOSED",
#                 "available_bikes": 22,
#                 "position": [
#                     50.842005,
#                     4.3305
#                 ],
#                 "last_update": "2024-02-26T12:45:46+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.3305,
#                     50.842005
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "02845b9dd850f0635aacc3f19d8f4b64f32bed20",
#             "fields": {
#                 "available_bike_stands": 16,
#                 "bike_stands": 25,
#                 "number": 325,
#                 "address": "HANKAR - CHEE DE WAVRE / WAVERSESTEENWEG 1208",
#                 "name": "325 - HANKAR",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 9,
#                 "position": [
#                     50.821441,
#                     4.406925
#                 ],
#                 "last_update": "2024-02-26T12:45:55+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.406925,
#                     50.821441
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "4bc5a94c53cf77eead4092bb3ce4866b74a61b78",
#             "fields": {
#                 "available_bike_stands": 8,
#                 "bike_stands": 18,
#                 "number": 288,
#                 "address": "HOUZEAU - AVENUE HOUZEAU 21 / HOUZEAULAAN 21",
#                 "name": "288 - HOUZEAU",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 10,
#                 "position": [
#                     50.80351,
#                     4.3589
#                 ],
#                 "last_update": "2024-02-26T12:45:59+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.3589,
#                     50.80351
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "6ac2d226ac3781e0ebfe9ec81de42a2b90c61ce7",
#             "fields": {
#                 "available_bike_stands": 16,
#                 "bike_stands": 25,
#                 "number": 324,
#                 "address": "THOMAS BALIS - CHEE DE WAVRE 1395 \u00e0 1403 / WAVERSESTEENWEG 1395 TOT 1403",
#                 "name": "324 - THOMAS BALIS",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 9,
#                 "position": [
#                     50.819641,
#                     4.412926
#                 ],
#                 "last_update": "2024-02-26T12:46:58+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.412926,
#                     50.819641
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "b198e05fdf3750da2523c3ca098014cfd9f720f0",
#             "fields": {
#                 "available_bike_stands": 18,
#                 "bike_stands": 42,
#                 "number": 141,
#                 "address": "GARE DU NORD/NOORDSTATION - PLACE SIMON BOLIVAR/ SIMON BOLIVARLAAN",
#                 "name": "141 - GARE DU NORD/NOORDSTATION",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 22,
#                 "position": [
#                     50.8607543151327,
#                     4.358885700202
#                 ],
#                 "last_update": "2024-02-26T12:46:17+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.358885700202,
#                     50.8607543151327
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "9b3612490f87bb75a71317fd89096297470aa074",
#             "fields": {
#                 "available_bike_stands": 7,
#                 "bike_stands": 21,
#                 "number": 3,
#                 "address": "PORTE DE FLANDRE/VLAAMSEPOORT - BLD DE NIEUPORT/NIEUWPOORTLAAN 1",
#                 "name": "003 - PORTE DE FLANDRE / VLAAMSEPOORT",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 12,
#                 "position": [
#                     50.853203,
#                     4.341823
#                 ],
#                 "last_update": "2024-02-26T12:45:59+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.341823,
#                     50.853203
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "4f04133e18b3d2974e14a85683746421bde35e19",
#             "fields": {
#                 "available_bike_stands": 6,
#                 "bike_stands": 20,
#                 "number": 331,
#                 "address": "GEORGES HENRI - AV GEORGES HENRI",
#                 "name": "331 - GEORGES HENRI",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.842319,
#                     4.406295
#                 ],
#                 "last_update": "2024-02-26T12:46:21+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.406295,
#                     50.842319
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "fd3f54734ca782db7ce240b1ef69f44586226fb5",
#             "fields": {
#                 "available_bike_stands": 17,
#                 "bike_stands": 22,
#                 "number": 326,
#                 "address": "ADEPS - CHEE DE WAVRE / WAVERSESTEENWEG 2057",
#                 "name": "326 - ADEPS",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 5,
#                 "position": [
#                     50.809406,
#                     4.443777
#                 ],
#                 "last_update": "2024-02-26T12:46:51+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.443777,
#                     50.809406
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "145eb11bd908b5351efdf433f341ebfed5bca597",
#             "fields": {
#                 "available_bike_stands": 15,
#                 "bike_stands": 25,
#                 "number": 212,
#                 "address": "THEO LAMBERT - BD THEO LAMBERT (FACE 66) / THEO LAMBERT LAAN (TEGENOVER 66)",
#                 "name": "212 - THEO LAMBERT",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 10,
#                 "position": [
#                     50.82701,
#                     4.292098
#                 ],
#                 "last_update": "2024-02-26T12:45:05+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.292098,
#                     50.82701
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "c2371b3c9f6d51534389171bb139c95c846990fd",
#             "fields": {
#                 "available_bike_stands": 12,
#                 "bike_stands": 19,
#                 "number": 231,
#                 "address": "KERSBEEK - AV KERSBEEK 107 / KERSBEEKLAAN 107",
#                 "name": "231 - KERSBEEK",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 7,
#                 "position": [
#                     50.805801,
#                     4.3194
#                 ],
#                 "last_update": "2024-02-26T12:49:38+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.3194,
#                     50.805801
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "96f74a455b50201ea897e3d82003043dbb6738e9",
#             "fields": {
#                 "available_bike_stands": 22,
#                 "bike_stands": 30,
#                 "number": 122,
#                 "address": "GARE D'ETTERBEEK/STATION VAN ETTERBEEK - BOULEVARD GENERAL JACQUES/GENERAAL JACQUESLAAN",
#                 "name": "122 - GARE D'ETTERBEEK",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 8,
#                 "position": [
#                     50.822207,
#                     4.389325
#                 ],
#                 "last_update": "2024-02-26T12:50:40+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.389325,
#                     50.822207
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "b518f93a4091ecec4f4ffd1feff47152b181753d",
#             "fields": {
#                 "available_bike_stands": 12,
#                 "bike_stands": 25,
#                 "number": 181,
#                 "address": "LOUIS TITZ - AVENUE DE LA CHASSE/ JACHTLAAN 182 - 184",
#                 "name": "181 - LOUIS TITZ",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 13,
#                 "position": [
#                     50.835723,
#                     4.394395
#                 ],
#                 "last_update": "2024-02-26T12:49:12+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.394395,
#                     50.835723
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "d30708e4dd134a031cc666e5dc09411d16840048",
#             "fields": {
#                 "available_bike_stands": 11,
#                 "bike_stands": 25,
#                 "number": 125,
#                 "address": "GEORGES BRUGMANN - PLACE GEORGES BRUGMANN/GEORGES BRUGMANNPLEIN N\u00b0 10 - 11",
#                 "name": "125 - GEORGES BRUGMANN",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.817392,
#                     4.354105
#                 ],
#                 "last_update": "2024-02-26T12:50:05+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.354105,
#                     50.817392
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "8d7874a4e943ec06405d2e071742735caac75122",
#             "fields": {
#                 "available_bike_stands": 9,
#                 "bike_stands": 20,
#                 "number": 335,
#                 "address": "THIRY - BD DE LA WOLUWE DVT 100",
#                 "name": "335 - THIRY",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 11,
#                 "position": [
#                     50.854231,
#                     4.444034
#                 ],
#                 "last_update": "2024-02-26T12:49:55+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.444034,
#                     50.854231
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "a188e2bd1d7c6c80a36135c96463ff8263dc7e42",
#             "fields": {
#                 "available_bike_stands": 16,
#                 "bike_stands": 25,
#                 "number": 232,
#                 "address": "DOMAINE / DOMEIN - AV DU DOMAINE (FACE 150) / DOMEINELAAN (VOOR 150)",
#                 "name": "232 - DOMAINE / DOMEIN",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 9,
#                 "position": [
#                     50.810875,
#                     4.329158
#                 ],
#                 "last_update": "2024-02-26T12:50:17+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.329158,
#                     50.810875
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "24cc0b983f4aceeb25365d7a9a310082ce6530b4",
#             "fields": {
#                 "available_bike_stands": 14,
#                 "bike_stands": 24,
#                 "number": 191,
#                 "address": "ARTAN - RUE CLAYS",
#                 "name": "191 - ARTAN",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 10,
#                 "position": [
#                     50.853973,
#                     4.38374
#                 ],
#                 "last_update": "2024-02-26T12:49:35+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.38374,
#                     50.853973
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "8bddf6ddf8d90f7f1ee8bbefe5354aedef865c62",
#             "fields": {
#                 "available_bike_stands": 13,
#                 "bike_stands": 25,
#                 "number": 86,
#                 "address": "MAISON COMMUNALE DE JETTE GEMEENTEHUIS - Chau. de Wemmel / Wemmelsesteenweg 102",
#                 "name": "086 - MAISON COMMUNALE DE JETTE GEMEENTEHUIS",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 12,
#                 "position": [
#                     50.876195,
#                     4.324477
#                 ],
#                 "last_update": "2024-02-26T12:50:17+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.324477,
#                     50.876195
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "137d9f0e0c6b2e1eb80bd95a28340630caf93152",
#             "fields": {
#                 "available_bike_stands": 8,
#                 "bike_stands": 25,
#                 "number": 154,
#                 "address": "PLASKY - SQUARE EUGENE PLASKY (FACE 100) / EUGENE PLASKYSQUARE (TEGENOVER 100)",
#                 "name": "154 - PLASKY/PLASKY",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 15,
#                 "position": [
#                     50.851241,
#                     4.396386
#                 ],
#                 "last_update": "2024-02-26T12:50:19+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.396386,
#                     50.851241
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "958b80968e2b2db6566694ff0fe17da75fbc9083",
#             "fields": {
#                 "available_bike_stands": 13,
#                 "bike_stands": 25,
#                 "number": 208,
#                 "address": "MELBA - AV NELLIE MELBA (FACE 1 a 9) / NELLIE MELBALAAN (TEGENOVER 1 tot 9)",
#                 "name": "208 - MELBA",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 12,
#                 "position": [
#                     50.832565,
#                     4.294311
#                 ],
#                 "last_update": "2024-02-26T12:51:04+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.294311,
#                     50.832565
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "86c606243ff7787f5b28618b9952da9962fcbc98",
#             "fields": {
#                 "available_bike_stands": 12,
#                 "bike_stands": 20,
#                 "number": 238,
#                 "address": "UNION SAINT-GILLOISE / SINT-GILLIS UNIE - CH DE BRUXELLES 366-362 / BRUSSELSESTEENWEG 366-362",
#                 "name": "238 - UNION SAINT-GILLOISE / SINT-GILLIS UNIE",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 7,
#                 "position": [
#                     50.820278,
#                     4.330802
#                 ],
#                 "last_update": "2024-02-26T12:50:38+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.330802,
#                     50.820278
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "bd709909adf723954aa94c2042cee6a695d66dc8",
#             "fields": {
#                 "available_bike_stands": 10,
#                 "bike_stands": 40,
#                 "number": 16,
#                 "address": "LOUISE/LOUIZA - PLACE LOUISE/LOUIZAPLEIN 53",
#                 "name": "016 - LOUISE / LOUIZA",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 30,
#                 "position": [
#                     50.835968,
#                     4.355508
#                 ],
#                 "last_update": "2024-02-26T12:50:45+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.355508,
#                     50.835968
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "b53ba1d9e1a4eb8cbb124b2e9d7a54be6b2a4166",
#             "fields": {
#                 "available_bike_stands": 11,
#                 "bike_stands": 25,
#                 "number": 123,
#                 "address": "BASCULE -  CHAUSSEE DE VLEURGAT (DEVANT 315 - 317) / VLEURGATSESTEENWEG  (N\u00b0 315 - 317)",
#                 "name": "123 - BASCULE",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.817507,
#                     4.366498
#                 ],
#                 "last_update": "2024-02-26T12:51:03+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.366498,
#                     50.817507
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "0d8f2a8390c4d497d62fe07053eb6d2f62ec7715",
#             "fields": {
#                 "available_bike_stands": 10,
#                 "bike_stands": 25,
#                 "number": 147,
#                 "address": "EMILE MAX LYCEE/LYCEUM EMILE MAX - CHAUSSEE D'HAECHT/ HAACHTSESTEENWEG 226 - 230",
#                 "name": "147 - EMILE MAX LYCEE/LYCEUM EMILE MAX",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.861874,
#                     4.372146
#                 ],
#                 "last_update": "2024-02-26T12:49:26+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.372146,
#                     50.861874
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "24a11b9f26c5945574222458ce5270db908bc5e2",
#             "fields": {
#                 "available_bike_stands": 8,
#                 "bike_stands": 20,
#                 "number": 47,
#                 "address": "LES QUAIS/KAAIEN - QUAI A LA CHAUX/KALKKAAI 1-2",
#                 "name": "047 - LES QUAIS / KAAIEN",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 9,
#                 "position": [
#                     50.854714,
#                     4.347151
#                 ],
#                 "last_update": "2024-02-26T12:50:49+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.347151,
#                     50.854714
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "3c1bded9eda4c5a9c32571276bcd2829b4537277",
#             "fields": {
#                 "available_bike_stands": 18,
#                 "bike_stands": 25,
#                 "number": 312,
#                 "address": "CENTRE CULTUREL / CULTUREEL CENTRUM - BD DU SOUVERAIN FACE 282 / VORSTLAAN VOOR 282",
#                 "name": "312 - CENTRE CULTUREL / CULTUREEL CENTRUM",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 6,
#                 "position": [
#                     50.816948,
#                     4.426551
#                 ],
#                 "last_update": "2024-02-26T12:49:21+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.426551,
#                     50.816948
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "28277f5dfe8ff6667e67ac678b04d191826d1260",
#             "fields": {
#                 "available_bike_stands": 9,
#                 "bike_stands": 25,
#                 "number": 239,
#                 "address": "DARWIN - AV. BRUGMANN / BRUGMANNLAAN 139-147",
#                 "name": "239 - DARWIN",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.817777,
#                     4.350406
#                 ],
#                 "last_update": "2024-02-26T12:50:31+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.350406,
#                     50.817777
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "0bbcce6be67f7e39d0e994b285d91287440f1a25",
#             "fields": {
#                 "available_bike_stands": 14,
#                 "bike_stands": 25,
#                 "number": 182,
#                 "address": "BOILEAU - BOULEVARD SAINT MICHEL / SINT-MICHIELSLAAN",
#                 "name": "182 - BOILEAU",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 11,
#                 "position": [
#                     50.83168,
#                     4.404769
#                 ],
#                 "last_update": "2024-02-26T12:50:14+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.404769,
#                     50.83168
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "2e8bc98a0f4a10084b5a66a446f816b12c3322cf",
#             "fields": {
#                 "available_bike_stands": 13,
#                 "bike_stands": 22,
#                 "number": 254,
#                 "address": "BASILIQUE / BASILIEK - AV JACQUES SERMON / JACUES SERMONLAAN",
#                 "name": "254 - BASILIQUE / BASILIEK",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 7,
#                 "position": [
#                     50.867393,
#                     4.320344
#                 ],
#                 "last_update": "2024-02-26T12:50:30+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.320344,
#                     50.867393
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "8cf2d384e35a0714e93b8cf08122b59adcde2916",
#             "fields": {
#                 "available_bike_stands": 6,
#                 "bike_stands": 20,
#                 "number": 63,
#                 "address": "JULES CESAR - AVENUE DE TERVUREN DEVANT / TERVURENLAAN VOOR 278",
#                 "name": "063 - JULES CESAR",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 14,
#                 "position": [
#                     50.834705,
#                     4.421643
#                 ],
#                 "last_update": "2024-02-26T12:49:52+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.421643,
#                     50.834705
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "46a38a73982960fbb7555f7c92eabb9f8c8cf9a2",
#             "fields": {
#                 "available_bike_stands": 4,
#                 "bike_stands": 20,
#                 "number": 364,
#                 "address": "DOCKS BRUXSEL - AVENUE JULES VAN PRAETLAAN",
#                 "name": "364 - DOCKS BRUXSEL",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 16,
#                 "position": [
#                     50.879086,
#                     4.374729
#                 ],
#                 "last_update": "2024-02-26T12:49:33+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.374729,
#                     50.879086
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "44c146194949424888b92e3f343a0d6ae23f084f",
#             "fields": {
#                 "available_bike_stands": 12,
#                 "bike_stands": 25,
#                 "number": 15,
#                 "address": "MONTGOMERY - AVENUE DE TERVUREN / TERVURENLAAN 136-138",
#                 "name": "015 - MONTGOMERY",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 13,
#                 "position": [
#                     50.837036,
#                     4.406826
#                 ],
#                 "last_update": "2024-02-26T12:49:24+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.406826,
#                     50.837036
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "5e99d2788d1b84e5afd7c725f578b5d8ad509e44",
#             "fields": {
#                 "available_bike_stands": 21,
#                 "bike_stands": 44,
#                 "number": 179,
#                 "address": "CELTES/KELTEN - AVENUE DE TERVUEREN (FACE AU 17) / TERVURENLAAN (TEGENOVER 17)",
#                 "name": "179 - CELTES/KELTEN",
#                 "bonus": "True",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 18,
#                 "position": [
#                     50.839217,
#                     4.398015
#                 ],
#                 "last_update": "2024-02-26T12:50:24+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.398015,
#                     50.839217
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "5e81b4798ceb2657cf5d9d431f30d200d69444c3",
#             "fields": {
#                 "available_bike_stands": 18,
#                 "bike_stands": 25,
#                 "number": 42,
#                 "address": "PORTE DE NINOVE / NINOOFSEPOORT - Pl. de Ninove x Bd de l'Abattoir / Ninoofseplein x Slachthuislaan",
#                 "name": "042 - PORTE DE NINOVE / NINOOFSEPOORT",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 7,
#                 "position": [
#                     50.84851,
#                     4.338064
#                 ],
#                 "last_update": "2024-02-26T12:49:50+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.338064,
#                     50.84851
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "ccadf97e1438ed1abeb0a3fb288a5f766a7206c1",
#             "fields": {
#                 "available_bike_stands": 11,
#                 "bike_stands": 22,
#                 "number": 148,
#                 "address": "GARE MEISER / MEISER STATION - AVENUE ROGIER/ ROGIERLAAN 377 - 379",
#                 "name": "148 - GARE MEISER/MEISER STATION",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 10,
#                 "position": [
#                     50.855629,
#                     4.394807
#                 ],
#                 "last_update": "2024-02-26T12:50:32+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.394807,
#                     50.855629
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "b9adac903756ae7a543c790719f5c3add942a0a4",
#             "fields": {
#                 "available_bike_stands": 8,
#                 "bike_stands": 20,
#                 "number": 327,
#                 "address": "SIBELGA - QUAI DES USINES / WERKHUIZENKAAI 16",
#                 "name": "327 - SIBELGA",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 11,
#                 "position": [
#                     50.874082,
#                     4.362205
#                 ],
#                 "last_update": "2024-02-26T12:49:48+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.362205,
#                     50.874082
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
#             "recordid": "fcb06f8b2e8885c44d5b21b3e51c4568518865b0",
#             "fields": {
#                 "available_bike_stands": 16,
#                 "bike_stands": 25,
#                 "number": 163,
#                 "address": "CHAZAL - AVENUE ERNEST CAMBIER (FACE 7)/ ERNEST CAMBIERLAAN (TEGENOVER 7)",
#                 "name": "163 - CHAZAL/CHAZAL",
#                 "bonus": "False",
#                 "banking": "False",
#                 "contract_name": "Bruxelles-Capitale",
#                 "status": "OPEN",
#                 "available_bikes": 9,
#                 "position": [
#                     50.859112,
#                     4.39157
#                 ],
#                 "last_update": "2024-02-26T12:50:07+00:00"
#             },
#             "geometry": {
#                 "type": "Point",
#                 "coordinates": [
#                     4.39157,
#                     50.859112
#                 ]
#             }
#         },
#         {
#             "datasetid": "jcdecaux-bike-stations-data-rt",
# ...
#                     "state": "displayed",
#                     "path": "138 - HOUFFALIZE"
#                 },
#                 {
#                     "name": "139 - LIEDTS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "139 - LIEDTS"
#                 },
#                 {
#                     "name": "140 - AZALEES/AZALEA",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "140 - AZALEES/AZALEA"
#                 },
#                 {
#                     "name": "141 - GARE DU NORD/NOORDSTATION",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "141 - GARE DU NORD/NOORDSTATION"
#                 },
#                 {
#                     "name": "142 - BIENFAITEURS/WELDOENERS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "142 - BIENFAITEURS/WELDOENERS"
#                 },
#                 {
#                     "name": "143 - RTL",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "143 - RTL"
#                 },
#                 {
#                     "name": "144 - SAINTE-MARIE/SINTE-MARIA",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "144 - SAINTE-MARIE/SINTE-MARIA"
#                 },
#                 {
#                     "name": "145 - COTEAUX/WIJNHEUVELEN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "145 - COTEAUX/WIJNHEUVELEN"
#                 },
#                 {
#                     "name": "146 - LEOPOLD III/LEOPOLD III",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "146 - LEOPOLD III/LEOPOLD III"
#                 },
#                 {
#                     "name": "147 - EMILE MAX LYCEE/LYCEUM EMILE MAX",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "147 - EMILE MAX LYCEE/LYCEUM EMILE MAX"
#                 },
#                 {
#                     "name": "148 - GARE MEISER/MEISER STATION",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "148 - GARE MEISER/MEISER STATION"
#                 },
#                 {
#                     "name": "149 - JULES LEBRUN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "149 - JULES LEBRUN"
#                 },
#                 {
#                     "name": "150 - MEISER/MEISER",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "150 - MEISER/MEISER"
#                 },
#                 {
#                     "name": "151 - LOUVAIN 488-494/LEUVEN 488-494",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "151 - LOUVAIN 488-494/LEUVEN 488-494"
#                 },
#                 {
#                     "name": "152 - PLACE DAILLY/DAILLYPLEIN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "152 - PLACE DAILLY/DAILLYPLEIN"
#                 },
#                 {
#                     "name": "153 - SQUARE ARMAND STEURS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "153 - SQUARE ARMAND STEURS"
#                 },
#                 {
#                     "name": "154 - PLASKY/PLASKY",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "154 - PLASKY/PLASKY"
#                 },
#                 {
#                     "name": "155 - LES MARRONNIERS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "155 - LES MARRONNIERS"
#                 },
#                 {
#                     "name": "156 - JAMBLINE DE MEUX/JAMBLINNE DE MEUX",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "156 - JAMBLINE DE MEUX/JAMBLINNE DE MEUX"
#                 },
#                 {
#                     "name": "157 - HELIOTROPES/HELIOTROPEN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "157 - HELIOTROPES/HELIOTROPEN"
#                 },
#                 {
#                     "name": "158 - VAN YSENDIJCK",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "158 - VAN YSENDIJCK"
#                 },
#                 {
#                     "name": "159 - MASUI",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "159 - MASUI"
#                 },
#                 {
#                     "name": "160 - ELISA",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "160 - ELISA"
#                 },
#                 {
#                     "name": "161 - DEMOLDER",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "161 - DEMOLDER"
#                 },
#                 {
#                     "name": "163 - CHAZAL/CHAZAL",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "163 - CHAZAL/CHAZAL"
#                 },
#                 {
#                     "name": "164 - KENNIS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "164 - KENNIS"
#                 },
#                 {
#                     "name": "165 - CIMETIERE DE JETTE / KERKHOF JETTE",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "165 - CIMETIERE DE JETTE / KERKHOF JETTE"
#                 },
#                 {
#                     "name": "166 - GC ESSEGEM",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "166 - GC ESSEGEM"
#                 },
#                 {
#                     "name": "167 - CHARLES V/KAREL V",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "167 - CHARLES V/KAREL V"
#                 },
#                 {
#                     "name": "168 - HOPITAL FRAN\u00c7AIS/FRANS HOSPITAAL",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "168 - HOPITAL FRAN\u00c7AIS/FRANS HOSPITAAL"
#                 },
#                 {
#                     "name": "169 - GEORGES EEKHOUD",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "169 - GEORGES EEKHOUD"
#                 },
#                 {
#                     "name": "170 - RIGA",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "170 - RIGA"
#                 },
#                 {
#                     "name": "171 - PISCINE LOUIS NAMECHE ZWEMBAD",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "171 - PISCINE LOUIS NAMECHE ZWEMBAD"
#                 },
#                 {
#                     "name": "172 - AEROPOLIS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "172 - AEROPOLIS"
#                 },
#                 {
#                     "name": "173 - BICHON",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "173 - BICHON"
#                 },
#                 {
#                     "name": "174 - MENNEKENS/MENNEKENS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "174 - MENNEKENS/MENNEKENS"
#                 },
#                 {
#                     "name": "175 - BEEKKANT",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "175 - BEEKKANT"
#                 },
#                 {
#                     "name": "176 - COLONEL BOURG/KOLONEL BOURG",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "176 - COLONEL BOURG/KOLONEL BOURG"
#                 },
#                 {
#                     "name": "177 - CHASSEURS ARDENNAIS/ARDENSE JAGERS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "177 - CHASSEURS ARDENNAIS/ARDENSE JAGERS"
#                 },
#                 {
#                     "name": "178 - DIAMANT/DIAMANT",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "178 - DIAMANT/DIAMANT"
#                 },
#                 {
#                     "name": "179 - CELTES/KELTEN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "179 - CELTES/KELTEN"
#                 },
#                 {
#                     "name": "180 - JOURDAN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "180 - JOURDAN"
#                 },
#                 {
#                     "name": "181 - LOUIS TITZ",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "181 - LOUIS TITZ"
#                 },
#                 {
#                     "name": "182 - BOILEAU",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "182 - BOILEAU"
#                 },
#                 {
#                     "name": "183 - LA CHASSE/JACHT",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "183 - LA CHASSE/JACHT"
#                 },
#                 {
#                     "name": "184 - PHILIPPE BAUCQ",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "184 - PHILIPPE BAUCQ"
#                 },
#                 {
#                     "name": "185 - PERE DE DEKEN/PATER DE DEKEN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "185 - PERE DE DEKEN/PATER DE DEKEN"
#                 },
#                 {
#                     "name": "186 - GENOT",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "186 - GENOT"
#                 },
#                 {
#                     "name": "187 - ARSENAL/ARSENAAL",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "187 - ARSENAL/ARSENAAL"
#                 },
#                 {
#                     "name": "188 - OSSEGHEM",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "188 - OSSEGHEM"
#                 },
#                 {
#                     "name": "189 - PLACE VAN MEYEL/VAN MEYELPLEIN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "189 - PLACE VAN MEYEL/VAN MEYELPLEIN"
#                 },
#                 {
#                     "name": "190 - TERDELT",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "190 - TERDELT"
#                 },
#                 {
#                     "name": "191 - ARTAN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "191 - ARTAN"
#                 },
#                 {
#                     "name": "192 - AUBERGE DE JEUNESSE",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "192 - AUBERGE DE JEUNESSE"
#                 },
#                 {
#                     "name": "193 - GARE DE L'OUEST",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "193 - GARE DE L'OUEST"
#                 },
#                 {
#                     "name": "194 - STUYVENBERG",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "194 - STUYVENBERG"
#                 },
#                 {
#                     "name": "196 - PRINCE DE LIEGE / PRINS VAN LUIK",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "196 - PRINCE DE LIEGE / PRINS VAN LUIK"
#                 },
#                 {
#                     "name": "197 - DE SMET",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "197 - DE SMET"
#                 },
#                 {
#                     "name": "198 - SCHEUT",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "198 - SCHEUT"
#                 },
#                 {
#                     "name": "199 - HENRI REY",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "199 - HENRI REY"
#                 },
#                 {
#                     "name": "200 - VETERANS COLONIAUX / KOLONIALE VETERANEN",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "200 - VETERANS COLONIAUX / KOLONIALE VETERANEN"
#                 },
#                 {
#                     "name": "201 - PETERBOS",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "201 - PETERBOS"
#                 },
#                 {
#                     "name": "202 - AUMALE",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "202 - AUMALE"
#                 },
#                 {
#                     "name": "203 - DEMOSTHENE",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "203 - DEMOSTHENE"
#                 },
#                 {
#                     "name": "205 - DE LINDE",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "205 - DE LINDE"
#                 },
#                 {
#                     "name": "206 - SAINT-GUIDON / SINT GUIDO",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "206 - SAINT-GUIDON / SINT GUIDO"
#                 },
#                 {
#                     "name": "207 - BIESTEBROECK / BIESTEBROEK",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "207 - BIESTEBROECK / BIESTEBROEK"
#                 },
#                 {
#                     "name": "208 - MELBA",
#                     "count": 1,
#                     "state": "displayed",
#                     "path": "208 - MELBA"
#                 }
#             ]
#         },
#         {
#             "name": "bonus",
#             "facets": [
#                 {
#                     "name": "False",
#                     "count": 293,
#                     "state": "displayed",
#                     "path": "False"
#                 },
#                 {
#                     "name": "True",
#                     "count": 58,
#                     "state": "displayed",
#                     "path": "True"
#                 }
#             ]
#         },
#         {
#             "name": "status",
#             "facets": [
#                 {
#                     "name": "OPEN",
#                     "count": 345,
#                     "state": "displayed",
#                     "path": "OPEN"
#                 },
#                 {
#                     "name": "CLOSED",
#                     "count": 6,
#                     "state": "displayed",
#                     "path": "CLOSED"
#                 }
#             ]
#         },
#         {
#             "name": "contract_name",
#             "facets": [
#                 {
#                     "name": "Bruxelles-Capitale",
#                     "count": 351,
#                     "state": "refined",
#                     "path": "Bruxelles-Capitale"
#                 }
#             ]
#         }
#     ]
# }

# %% [markdown]
# Another approach is to look at it step by step:

# %%
type(data)
# Out:
# dict

# %% [markdown]
# Data is a python dictionary => `{key3:value3, key1:value1, key2:value2,...}`
#
# **Dictionaries don't have an order!** but are a set of keys with linked values, where keys can be strings or ints and values can be (nearly) anything (list, dict, string, int, object, ...).

# %%
data.keys() # Check what are the keys of the dict
# Out:
# dict_keys(['nhits', 'parameters', 'records', 'facet_groups'])

# %%
data['nhits'] # check what is value of key 'nhits'
# Out:
# 351

# %%
data['parameters'] # check what is value of key 'parameters'
# Out:
# {'dataset': 'jcdecaux-bike-stations-data-rt',
#  'rows': 50,
#  'start': 0,
#  'facet': ['banking', 'name', 'bonus', 'status', 'contract_name'],
#  'format': 'json',
#  'timezone': 'UTC'}

# %%
data['records']# check what is value of key 'records'
# Out:
# [{'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '6e8b2f6a144a66d65da8d2974bd1a4db0eee4841',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 25,
#    'number': 305,
#    'address': 'PETER BENOIT - PLACE PETER BENOIT PLAATS 2-4',
#    'name': '305 - PETER BENOIT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.895592, 4.387965],
#    'last_update': '2024-02-26T12:45:24+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.387965, 50.895592]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '39042b9903ec9a87d9fd670c5999fb52ad8d9e6d',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 25,
#    'number': 200,
#    'address': 'VETERANS COLONIAUX / KOLONIALE VETERANEN - BD JULES GRAINDOR / JULES GRAINDORLAAN',
#    'name': '200 - VETERANS COLONIAUX / KOLONIALE VETERANEN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.843967, 4.313537],
#    'last_update': '2024-02-26T12:46:03+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.313537, 50.843967]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'f6039901b8d09af2397b1edf8f6c805fa99be5e4',
#   'fields': {'available_bike_stands': 14,
#    'bike_stands': 25,
#    'number': 43,
#    'address': 'JOSEPH II/JOZEF II - RUE JOSEPH II/JOZEF II-STRAAT',
#    'name': '043 - JOSEPH II / JOZEF II',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.845256, 4.374501],
#    'last_update': '2024-02-26T12:46:42+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.374501, 50.845256]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '89468bd2064d390b18663917ff6ec2aef6318f05',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 25,
#    'number': 271,
#    'address': 'DUBOIS - BD EMILE MACHTENS/LAAN 102-104',
#    'name': '271 - DUBOIS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.851158, 4.309591],
#    'last_update': '2024-02-26T12:46:37+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.309591, 50.851158]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'fdbf237799778416d27a384011b8e3844e61eff8',
#   'fields': {'available_bike_stands': 19,
#    'bike_stands': 25,
#    'number': 131,
#    'address': 'JARDIN MASSART - AV HERMANN DEBROUXLAAN',
#    'name': '131 - JARDIN MASSART',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 5,
#    'position': [50.81329, 4.434751],
#    'last_update': '2024-02-26T12:46:42+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.434751, 50.81329]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '614111dc8bb4d50ca6cbbd9fe20f7d014cbaee80',
#   'fields': {'available_bike_stands': 21,
#    'bike_stands': 30,
#    'number': 214,
#    'address': 'CAMPUS CERIA / CAMPUS VAN CERIA - AV EMILE GRYSON (FACE 6 a 10) / EMILE GRYSONLAAN (TEGENOVER 6 tot 10)',
#    'name': '214 - CAMPUS CERIA / CAMPUS VAN CERIA',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.816002, 4.295121],
#    'last_update': '2024-02-26T12:46:46+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.295121, 50.816002]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'ba8d1161f59cd55b73aef06c2a8cfe5bcdaa9531',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 20,
#    'number': 343,
#    'address': 'VANDENDRIESCH - RUE J-B VANDENDRIESCH 22-24',
#    'name': '343 - VANDENDRIESCH',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 8,
#    'position': [50.861788, 4.292913],
#    'last_update': '2024-02-26T12:45:51+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.292913, 50.861788]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '92ca851251195416b0f7f203cd8a19214e4a55ca',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 207,
#    'address': 'BIESTEBROECK / BIESTEBROEK - CHEE DE MONS (FACE AU 518-526) / BERGENSESTEENWEG (TEGENOVER 518-526)',
#    'name': '207 - BIESTEBROECK / BIESTEBROEK',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 8,
#    'position': [50.833424, 4.313378],
#    'last_update': '2024-02-26T12:46:36+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.313378, 50.833424]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '0e567ef66cc50a463700c462cd3673a903904497',
#   'fields': {'available_bike_stands': 7,
#    'bike_stands': 35,
#    'number': 34,
#    'address': 'FONTAINAS - BLD ANSPACH N°180 A 192/ANSPACHLAAN N°180 TOT 192',
#    'name': '034 - FONTAINAS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 28,
#    'position': [50.84563, 4.346942],
#    'last_update': '2024-02-26T12:45:58+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.346942, 50.84563]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '4998d5d5e140b1d08c6a9fc186e979dbca73ddc5',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 24,
#    'number': 230,
#    'address': 'BERKENDAEL / BERKENDAAL - AVENUE ALBERT / ALBERTLAAN 134',
#    'name': '230 - BERKENDAEL / BERKENDAAL',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.818382, 4.346061],
#    'last_update': '2024-02-26T12:45:14+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.346061, 50.818382]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'd7f232853d00c3ebb85d915dbfa2dab1dbebf0f9',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 25,
#    'number': 152,
#    'address': 'PLACE DAILLY / DAILLYPLEIN - PLACE DAILLY / DAILLYPLEIN 24 - 25',
#    'name': '152 - PLACE DAILLY/DAILLYPLEIN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 16,
#    'position': [50.852389, 4.387373],
#    'last_update': '2024-02-26T12:47:00+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.387373, 50.852389]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '06268ab5d44788e8d64bfffd57eb362894c20e3d',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 25,
#    'number': 176,
#    'address': 'COLONEL BOURG/KOLONEL BOURG - RUE COLONEL BOURG/ KOLONEL BOURGSTRAAT 104',
#    'name': '176 - COLONEL BOURG/KOLONEL BOURG',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.852356, 4.408635],
#    'last_update': '2024-02-26T12:46:06+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.408635, 50.852356]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '30f64650f0dc443162a433d6dea0b5e45f9400a9',
#   'fields': {'available_bike_stands': 5,
#    'bike_stands': 27,
#    'number': 28,
#    'address': 'CLEMENCEAU - CHEE DE MONS/ BERGENSE STEENWEG 159-161-163',
#    'name': '028 - CLEMENCEAU',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'CLOSED',
#    'available_bikes': 22,
#    'position': [50.842005, 4.3305],
#    'last_update': '2024-02-26T12:45:46+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.3305, 50.842005]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '02845b9dd850f0635aacc3f19d8f4b64f32bed20',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 325,
#    'address': 'HANKAR - CHEE DE WAVRE / WAVERSESTEENWEG 1208',
#    'name': '325 - HANKAR',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.821441, 4.406925],
#    'last_update': '2024-02-26T12:45:55+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.406925, 50.821441]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '4bc5a94c53cf77eead4092bb3ce4866b74a61b78',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 18,
#    'number': 288,
#    'address': 'HOUZEAU - AVENUE HOUZEAU 21 / HOUZEAULAAN 21',
#    'name': '288 - HOUZEAU',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.80351, 4.3589],
#    'last_update': '2024-02-26T12:45:59+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.3589, 50.80351]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '6ac2d226ac3781e0ebfe9ec81de42a2b90c61ce7',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 324,
#    'address': 'THOMAS BALIS - CHEE DE WAVRE 1395 à 1403 / WAVERSESTEENWEG 1395 TOT 1403',
#    'name': '324 - THOMAS BALIS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.819641, 4.412926],
#    'last_update': '2024-02-26T12:46:58+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.412926, 50.819641]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b198e05fdf3750da2523c3ca098014cfd9f720f0',
#   'fields': {'available_bike_stands': 18,
#    'bike_stands': 42,
#    'number': 141,
#    'address': 'GARE DU NORD/NOORDSTATION - PLACE SIMON BOLIVAR/ SIMON BOLIVARLAAN',
#    'name': '141 - GARE DU NORD/NOORDSTATION',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 22,
#    'position': [50.8607543151327, 4.358885700202],
#    'last_update': '2024-02-26T12:46:17+00:00'},
#   'geometry': {'type': 'Point',
#    'coordinates': [4.358885700202, 50.8607543151327]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '9b3612490f87bb75a71317fd89096297470aa074',
#   'fields': {'available_bike_stands': 7,
#    'bike_stands': 21,
#    'number': 3,
#    'address': 'PORTE DE FLANDRE/VLAAMSEPOORT - BLD DE NIEUPORT/NIEUWPOORTLAAN 1',
#    'name': '003 - PORTE DE FLANDRE / VLAAMSEPOORT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.853203, 4.341823],
#    'last_update': '2024-02-26T12:45:59+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.341823, 50.853203]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '4f04133e18b3d2974e14a85683746421bde35e19',
#   'fields': {'available_bike_stands': 6,
#    'bike_stands': 20,
#    'number': 331,
#    'address': 'GEORGES HENRI - AV GEORGES HENRI',
#    'name': '331 - GEORGES HENRI',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.842319, 4.406295],
#    'last_update': '2024-02-26T12:46:21+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.406295, 50.842319]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'fd3f54734ca782db7ce240b1ef69f44586226fb5',
#   'fields': {'available_bike_stands': 17,
#    'bike_stands': 22,
#    'number': 326,
#    'address': 'ADEPS - CHEE DE WAVRE / WAVERSESTEENWEG 2057',
#    'name': '326 - ADEPS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 5,
#    'position': [50.809406, 4.443777],
#    'last_update': '2024-02-26T12:46:51+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.443777, 50.809406]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '145eb11bd908b5351efdf433f341ebfed5bca597',
#   'fields': {'available_bike_stands': 15,
#    'bike_stands': 25,
#    'number': 212,
#    'address': 'THEO LAMBERT - BD THEO LAMBERT (FACE 66) / THEO LAMBERT LAAN (TEGENOVER 66)',
#    'name': '212 - THEO LAMBERT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.82701, 4.292098],
#    'last_update': '2024-02-26T12:45:05+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.292098, 50.82701]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'c2371b3c9f6d51534389171bb139c95c846990fd',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 19,
#    'number': 231,
#    'address': 'KERSBEEK - AV KERSBEEK 107 / KERSBEEKLAAN 107',
#    'name': '231 - KERSBEEK',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.805801, 4.3194],
#    'last_update': '2024-02-26T12:49:38+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.3194, 50.805801]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '96f74a455b50201ea897e3d82003043dbb6738e9',
#   'fields': {'available_bike_stands': 22,
#    'bike_stands': 30,
#    'number': 122,
#    'address': "GARE D'ETTERBEEK/STATION VAN ETTERBEEK - BOULEVARD GENERAL JACQUES/GENERAAL JACQUESLAAN",
#    'name': "122 - GARE D'ETTERBEEK",
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 8,
#    'position': [50.822207, 4.389325],
#    'last_update': '2024-02-26T12:50:40+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.389325, 50.822207]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b518f93a4091ecec4f4ffd1feff47152b181753d',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 25,
#    'number': 181,
#    'address': 'LOUIS TITZ - AVENUE DE LA CHASSE/ JACHTLAAN 182 - 184',
#    'name': '181 - LOUIS TITZ',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 13,
#    'position': [50.835723, 4.394395],
#    'last_update': '2024-02-26T12:49:12+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.394395, 50.835723]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'd30708e4dd134a031cc666e5dc09411d16840048',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 25,
#    'number': 125,
#    'address': 'GEORGES BRUGMANN - PLACE GEORGES BRUGMANN/GEORGES BRUGMANNPLEIN N° 10 - 11',
#    'name': '125 - GEORGES BRUGMANN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.817392, 4.354105],
#    'last_update': '2024-02-26T12:50:05+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.354105, 50.817392]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '8d7874a4e943ec06405d2e071742735caac75122',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 20,
#    'number': 335,
#    'address': 'THIRY - BD DE LA WOLUWE DVT 100',
#    'name': '335 - THIRY',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.854231, 4.444034],
#    'last_update': '2024-02-26T12:49:55+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.444034, 50.854231]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'a188e2bd1d7c6c80a36135c96463ff8263dc7e42',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 232,
#    'address': 'DOMAINE / DOMEIN - AV DU DOMAINE (FACE 150) / DOMEINELAAN (VOOR 150)',
#    'name': '232 - DOMAINE / DOMEIN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.810875, 4.329158],
#    'last_update': '2024-02-26T12:50:17+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.329158, 50.810875]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '24cc0b983f4aceeb25365d7a9a310082ce6530b4',
#   'fields': {'available_bike_stands': 14,
#    'bike_stands': 24,
#    'number': 191,
#    'address': 'ARTAN - RUE CLAYS',
#    'name': '191 - ARTAN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.853973, 4.38374],
#    'last_update': '2024-02-26T12:49:35+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.38374, 50.853973]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '8bddf6ddf8d90f7f1ee8bbefe5354aedef865c62',
#   'fields': {'available_bike_stands': 13,
#    'bike_stands': 25,
#    'number': 86,
#    'address': 'MAISON COMMUNALE DE JETTE GEMEENTEHUIS - Chau. de Wemmel / Wemmelsesteenweg 102',
#    'name': '086 - MAISON COMMUNALE DE JETTE GEMEENTEHUIS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.876195, 4.324477],
#    'last_update': '2024-02-26T12:50:17+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.324477, 50.876195]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '137d9f0e0c6b2e1eb80bd95a28340630caf93152',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 25,
#    'number': 154,
#    'address': 'PLASKY - SQUARE EUGENE PLASKY (FACE 100) / EUGENE PLASKYSQUARE (TEGENOVER 100)',
#    'name': '154 - PLASKY/PLASKY',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.851241, 4.396386],
#    'last_update': '2024-02-26T12:50:19+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.396386, 50.851241]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '958b80968e2b2db6566694ff0fe17da75fbc9083',
#   'fields': {'available_bike_stands': 13,
#    'bike_stands': 25,
#    'number': 208,
#    'address': 'MELBA - AV NELLIE MELBA (FACE 1 a 9) / NELLIE MELBALAAN (TEGENOVER 1 tot 9)',
#    'name': '208 - MELBA',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.832565, 4.294311],
#    'last_update': '2024-02-26T12:51:04+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.294311, 50.832565]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '86c606243ff7787f5b28618b9952da9962fcbc98',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 20,
#    'number': 238,
#    'address': 'UNION SAINT-GILLOISE / SINT-GILLIS UNIE - CH DE BRUXELLES 366-362 / BRUSSELSESTEENWEG 366-362',
#    'name': '238 - UNION SAINT-GILLOISE / SINT-GILLIS UNIE',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.820278, 4.330802],
#    'last_update': '2024-02-26T12:50:38+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.330802, 50.820278]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'bd709909adf723954aa94c2042cee6a695d66dc8',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 40,
#    'number': 16,
#    'address': 'LOUISE/LOUIZA - PLACE LOUISE/LOUIZAPLEIN 53',
#    'name': '016 - LOUISE / LOUIZA',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 30,
#    'position': [50.835968, 4.355508],
#    'last_update': '2024-02-26T12:50:45+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.355508, 50.835968]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b53ba1d9e1a4eb8cbb124b2e9d7a54be6b2a4166',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 25,
#    'number': 123,
#    'address': 'BASCULE -  CHAUSSEE DE VLEURGAT (DEVANT 315 - 317) / VLEURGATSESTEENWEG  (N° 315 - 317)',
#    'name': '123 - BASCULE',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.817507, 4.366498],
#    'last_update': '2024-02-26T12:51:03+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.366498, 50.817507]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '0d8f2a8390c4d497d62fe07053eb6d2f62ec7715',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 25,
#    'number': 147,
#    'address': "EMILE MAX LYCEE/LYCEUM EMILE MAX - CHAUSSEE D'HAECHT/ HAACHTSESTEENWEG 226 - 230",
#    'name': '147 - EMILE MAX LYCEE/LYCEUM EMILE MAX',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.861874, 4.372146],
#    'last_update': '2024-02-26T12:49:26+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.372146, 50.861874]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '24a11b9f26c5945574222458ce5270db908bc5e2',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 20,
#    'number': 47,
#    'address': 'LES QUAIS/KAAIEN - QUAI A LA CHAUX/KALKKAAI 1-2',
#    'name': '047 - LES QUAIS / KAAIEN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.854714, 4.347151],
#    'last_update': '2024-02-26T12:50:49+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.347151, 50.854714]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '3c1bded9eda4c5a9c32571276bcd2829b4537277',
#   'fields': {'available_bike_stands': 18,
#    'bike_stands': 25,
#    'number': 312,
#    'address': 'CENTRE CULTUREL / CULTUREEL CENTRUM - BD DU SOUVERAIN FACE 282 / VORSTLAAN VOOR 282',
#    'name': '312 - CENTRE CULTUREL / CULTUREEL CENTRUM',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 6,
#    'position': [50.816948, 4.426551],
#    'last_update': '2024-02-26T12:49:21+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.426551, 50.816948]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '28277f5dfe8ff6667e67ac678b04d191826d1260',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 25,
#    'number': 239,
#    'address': 'DARWIN - AV. BRUGMANN / BRUGMANNLAAN 139-147',
#    'name': '239 - DARWIN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.817777, 4.350406],
#    'last_update': '2024-02-26T12:50:31+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.350406, 50.817777]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '0bbcce6be67f7e39d0e994b285d91287440f1a25',
#   'fields': {'available_bike_stands': 14,
#    'bike_stands': 25,
#    'number': 182,
#    'address': 'BOILEAU - BOULEVARD SAINT MICHEL / SINT-MICHIELSLAAN',
#    'name': '182 - BOILEAU',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.83168, 4.404769],
#    'last_update': '2024-02-26T12:50:14+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.404769, 50.83168]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '2e8bc98a0f4a10084b5a66a446f816b12c3322cf',
#   'fields': {'available_bike_stands': 13,
#    'bike_stands': 22,
#    'number': 254,
#    'address': 'BASILIQUE / BASILIEK - AV JACQUES SERMON / JACUES SERMONLAAN',
#    'name': '254 - BASILIQUE / BASILIEK',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.867393, 4.320344],
#    'last_update': '2024-02-26T12:50:30+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.320344, 50.867393]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '8cf2d384e35a0714e93b8cf08122b59adcde2916',
#   'fields': {'available_bike_stands': 6,
#    'bike_stands': 20,
#    'number': 63,
#    'address': 'JULES CESAR - AVENUE DE TERVUREN DEVANT / TERVURENLAAN VOOR 278',
#    'name': '063 - JULES CESAR',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.834705, 4.421643],
#    'last_update': '2024-02-26T12:49:52+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.421643, 50.834705]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '46a38a73982960fbb7555f7c92eabb9f8c8cf9a2',
#   'fields': {'available_bike_stands': 4,
#    'bike_stands': 20,
#    'number': 364,
#    'address': 'DOCKS BRUXSEL - AVENUE JULES VAN PRAETLAAN',
#    'name': '364 - DOCKS BRUXSEL',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 16,
#    'position': [50.879086, 4.374729],
#    'last_update': '2024-02-26T12:49:33+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.374729, 50.879086]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '44c146194949424888b92e3f343a0d6ae23f084f',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 25,
#    'number': 15,
#    'address': 'MONTGOMERY - AVENUE DE TERVUREN / TERVURENLAAN 136-138',
#    'name': '015 - MONTGOMERY',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 13,
#    'position': [50.837036, 4.406826],
#    'last_update': '2024-02-26T12:49:24+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.406826, 50.837036]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '5e99d2788d1b84e5afd7c725f578b5d8ad509e44',
#   'fields': {'available_bike_stands': 21,
#    'bike_stands': 44,
#    'number': 179,
#    'address': 'CELTES/KELTEN - AVENUE DE TERVUEREN (FACE AU 17) / TERVURENLAAN (TEGENOVER 17)',
#    'name': '179 - CELTES/KELTEN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 18,
#    'position': [50.839217, 4.398015],
#    'last_update': '2024-02-26T12:50:24+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.398015, 50.839217]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '5e81b4798ceb2657cf5d9d431f30d200d69444c3',
#   'fields': {'available_bike_stands': 18,
#    'bike_stands': 25,
#    'number': 42,
#    'address': "PORTE DE NINOVE / NINOOFSEPOORT - Pl. de Ninove x Bd de l'Abattoir / Ninoofseplein x Slachthuislaan",
#    'name': '042 - PORTE DE NINOVE / NINOOFSEPOORT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.84851, 4.338064],
#    'last_update': '2024-02-26T12:49:50+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.338064, 50.84851]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'ccadf97e1438ed1abeb0a3fb288a5f766a7206c1',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 22,
#    'number': 148,
#    'address': 'GARE MEISER / MEISER STATION - AVENUE ROGIER/ ROGIERLAAN 377 - 379',
#    'name': '148 - GARE MEISER/MEISER STATION',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.855629, 4.394807],
#    'last_update': '2024-02-26T12:50:32+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.394807, 50.855629]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b9adac903756ae7a543c790719f5c3add942a0a4',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 20,
#    'number': 327,
#    'address': 'SIBELGA - QUAI DES USINES / WERKHUIZENKAAI 16',
#    'name': '327 - SIBELGA',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.874082, 4.362205],
#    'last_update': '2024-02-26T12:49:48+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.362205, 50.874082]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'fcb06f8b2e8885c44d5b21b3e51c4568518865b0',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 163,
#    'address': 'CHAZAL - AVENUE ERNEST CAMBIER (FACE 7)/ ERNEST CAMBIERLAAN (TEGENOVER 7)',
#    'name': '163 - CHAZAL/CHAZAL',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.859112, 4.39157],
#    'last_update': '2024-02-26T12:50:07+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.39157, 50.859112]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '5e4f5c3b767b2e15827c2686434dcb06db0bee23',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 20,
#    'number': 334,
#    'address': 'MARCEL THIRY - AV MARCEL THIRY FACE 23',
#    'name': '334 - MARCEL THIRY',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.855593, 4.439625],
#    'last_update': '2024-02-26T12:49:22+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.439625, 50.855593]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '84e810acb99e02b68fab53b026991b46f4e63ba1',
#   'fields': {'available_bike_stands': 6,
#    'bike_stands': 25,
#    'number': 276,
#    'address': 'CROIX DE GUERRES / OORLOGSKRUISEN - AVENUE DES CROIX DE GUERRE / OORLOGSKRUISENLAAN 116',
#    'name': '276 - CROIX DE GUERRES / OORLOGSKRUISEN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 19,
#    'position': [50.889748, 4.380755],
#    'last_update': '2024-02-26T12:50:09+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.380755, 50.889748]}}]

# %%
type(data['records']) # how are stored the records ?
# Out:
# list

# %%
len(data['records']) # How many records do we have (remember we put &rows=50 in the URL/API call)
# Out:
# 50

# %% [markdown]
# Let's look at one arbitrary record:

# %%
data['records'][7]
# Out:
# {'datasetid': 'jcdecaux-bike-stations-data-rt',
#  'recordid': '92ca851251195416b0f7f203cd8a19214e4a55ca',
#  'fields': {'available_bike_stands': 16,
#   'bike_stands': 25,
#   'number': 207,
#   'address': 'BIESTEBROECK / BIESTEBROEK - CHEE DE MONS (FACE AU 518-526) / BERGENSESTEENWEG (TEGENOVER 518-526)',
#   'name': '207 - BIESTEBROECK / BIESTEBROEK',
#   'bonus': 'False',
#   'banking': 'False',
#   'contract_name': 'Bruxelles-Capitale',
#   'status': 'OPEN',
#   'available_bikes': 8,
#   'position': [50.833424, 4.313378],
#   'last_update': '2024-02-26T12:46:36+00:00'},
#  'geometry': {'type': 'Point', 'coordinates': [4.313378, 50.833424]}}

# %%
#find name of station
print(data['records'][7]['fields']['name'])
# Out:
# 207 - BIESTEBROECK / BIESTEBROEK

# %% [markdown]
# So the stations info is saved in a list with each element of the list is a dictionary with the info about a particular station

# %%
stations = data['records'] # let's save it in a separate variable
stations
# Out:
# [{'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '6e8b2f6a144a66d65da8d2974bd1a4db0eee4841',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 25,
#    'number': 305,
#    'address': 'PETER BENOIT - PLACE PETER BENOIT PLAATS 2-4',
#    'name': '305 - PETER BENOIT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.895592, 4.387965],
#    'last_update': '2024-02-26T12:45:24+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.387965, 50.895592]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '39042b9903ec9a87d9fd670c5999fb52ad8d9e6d',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 25,
#    'number': 200,
#    'address': 'VETERANS COLONIAUX / KOLONIALE VETERANEN - BD JULES GRAINDOR / JULES GRAINDORLAAN',
#    'name': '200 - VETERANS COLONIAUX / KOLONIALE VETERANEN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.843967, 4.313537],
#    'last_update': '2024-02-26T12:46:03+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.313537, 50.843967]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'f6039901b8d09af2397b1edf8f6c805fa99be5e4',
#   'fields': {'available_bike_stands': 14,
#    'bike_stands': 25,
#    'number': 43,
#    'address': 'JOSEPH II/JOZEF II - RUE JOSEPH II/JOZEF II-STRAAT',
#    'name': '043 - JOSEPH II / JOZEF II',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.845256, 4.374501],
#    'last_update': '2024-02-26T12:46:42+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.374501, 50.845256]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '89468bd2064d390b18663917ff6ec2aef6318f05',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 25,
#    'number': 271,
#    'address': 'DUBOIS - BD EMILE MACHTENS/LAAN 102-104',
#    'name': '271 - DUBOIS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.851158, 4.309591],
#    'last_update': '2024-02-26T12:46:37+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.309591, 50.851158]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'fdbf237799778416d27a384011b8e3844e61eff8',
#   'fields': {'available_bike_stands': 19,
#    'bike_stands': 25,
#    'number': 131,
#    'address': 'JARDIN MASSART - AV HERMANN DEBROUXLAAN',
#    'name': '131 - JARDIN MASSART',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 5,
#    'position': [50.81329, 4.434751],
#    'last_update': '2024-02-26T12:46:42+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.434751, 50.81329]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '614111dc8bb4d50ca6cbbd9fe20f7d014cbaee80',
#   'fields': {'available_bike_stands': 21,
#    'bike_stands': 30,
#    'number': 214,
#    'address': 'CAMPUS CERIA / CAMPUS VAN CERIA - AV EMILE GRYSON (FACE 6 a 10) / EMILE GRYSONLAAN (TEGENOVER 6 tot 10)',
#    'name': '214 - CAMPUS CERIA / CAMPUS VAN CERIA',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.816002, 4.295121],
#    'last_update': '2024-02-26T12:46:46+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.295121, 50.816002]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'ba8d1161f59cd55b73aef06c2a8cfe5bcdaa9531',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 20,
#    'number': 343,
#    'address': 'VANDENDRIESCH - RUE J-B VANDENDRIESCH 22-24',
#    'name': '343 - VANDENDRIESCH',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 8,
#    'position': [50.861788, 4.292913],
#    'last_update': '2024-02-26T12:45:51+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.292913, 50.861788]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '92ca851251195416b0f7f203cd8a19214e4a55ca',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 207,
#    'address': 'BIESTEBROECK / BIESTEBROEK - CHEE DE MONS (FACE AU 518-526) / BERGENSESTEENWEG (TEGENOVER 518-526)',
#    'name': '207 - BIESTEBROECK / BIESTEBROEK',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 8,
#    'position': [50.833424, 4.313378],
#    'last_update': '2024-02-26T12:46:36+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.313378, 50.833424]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '0e567ef66cc50a463700c462cd3673a903904497',
#   'fields': {'available_bike_stands': 7,
#    'bike_stands': 35,
#    'number': 34,
#    'address': 'FONTAINAS - BLD ANSPACH N°180 A 192/ANSPACHLAAN N°180 TOT 192',
#    'name': '034 - FONTAINAS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 28,
#    'position': [50.84563, 4.346942],
#    'last_update': '2024-02-26T12:45:58+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.346942, 50.84563]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '4998d5d5e140b1d08c6a9fc186e979dbca73ddc5',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 24,
#    'number': 230,
#    'address': 'BERKENDAEL / BERKENDAAL - AVENUE ALBERT / ALBERTLAAN 134',
#    'name': '230 - BERKENDAEL / BERKENDAAL',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.818382, 4.346061],
#    'last_update': '2024-02-26T12:45:14+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.346061, 50.818382]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'd7f232853d00c3ebb85d915dbfa2dab1dbebf0f9',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 25,
#    'number': 152,
#    'address': 'PLACE DAILLY / DAILLYPLEIN - PLACE DAILLY / DAILLYPLEIN 24 - 25',
#    'name': '152 - PLACE DAILLY/DAILLYPLEIN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 16,
#    'position': [50.852389, 4.387373],
#    'last_update': '2024-02-26T12:47:00+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.387373, 50.852389]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '06268ab5d44788e8d64bfffd57eb362894c20e3d',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 25,
#    'number': 176,
#    'address': 'COLONEL BOURG/KOLONEL BOURG - RUE COLONEL BOURG/ KOLONEL BOURGSTRAAT 104',
#    'name': '176 - COLONEL BOURG/KOLONEL BOURG',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.852356, 4.408635],
#    'last_update': '2024-02-26T12:46:06+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.408635, 50.852356]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '30f64650f0dc443162a433d6dea0b5e45f9400a9',
#   'fields': {'available_bike_stands': 5,
#    'bike_stands': 27,
#    'number': 28,
#    'address': 'CLEMENCEAU - CHEE DE MONS/ BERGENSE STEENWEG 159-161-163',
#    'name': '028 - CLEMENCEAU',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'CLOSED',
#    'available_bikes': 22,
#    'position': [50.842005, 4.3305],
#    'last_update': '2024-02-26T12:45:46+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.3305, 50.842005]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '02845b9dd850f0635aacc3f19d8f4b64f32bed20',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 325,
#    'address': 'HANKAR - CHEE DE WAVRE / WAVERSESTEENWEG 1208',
#    'name': '325 - HANKAR',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.821441, 4.406925],
#    'last_update': '2024-02-26T12:45:55+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.406925, 50.821441]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '4bc5a94c53cf77eead4092bb3ce4866b74a61b78',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 18,
#    'number': 288,
#    'address': 'HOUZEAU - AVENUE HOUZEAU 21 / HOUZEAULAAN 21',
#    'name': '288 - HOUZEAU',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.80351, 4.3589],
#    'last_update': '2024-02-26T12:45:59+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.3589, 50.80351]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '6ac2d226ac3781e0ebfe9ec81de42a2b90c61ce7',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 324,
#    'address': 'THOMAS BALIS - CHEE DE WAVRE 1395 à 1403 / WAVERSESTEENWEG 1395 TOT 1403',
#    'name': '324 - THOMAS BALIS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.819641, 4.412926],
#    'last_update': '2024-02-26T12:46:58+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.412926, 50.819641]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b198e05fdf3750da2523c3ca098014cfd9f720f0',
#   'fields': {'available_bike_stands': 18,
#    'bike_stands': 42,
#    'number': 141,
#    'address': 'GARE DU NORD/NOORDSTATION - PLACE SIMON BOLIVAR/ SIMON BOLIVARLAAN',
#    'name': '141 - GARE DU NORD/NOORDSTATION',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 22,
#    'position': [50.8607543151327, 4.358885700202],
#    'last_update': '2024-02-26T12:46:17+00:00'},
#   'geometry': {'type': 'Point',
#    'coordinates': [4.358885700202, 50.8607543151327]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '9b3612490f87bb75a71317fd89096297470aa074',
#   'fields': {'available_bike_stands': 7,
#    'bike_stands': 21,
#    'number': 3,
#    'address': 'PORTE DE FLANDRE/VLAAMSEPOORT - BLD DE NIEUPORT/NIEUWPOORTLAAN 1',
#    'name': '003 - PORTE DE FLANDRE / VLAAMSEPOORT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.853203, 4.341823],
#    'last_update': '2024-02-26T12:45:59+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.341823, 50.853203]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '4f04133e18b3d2974e14a85683746421bde35e19',
#   'fields': {'available_bike_stands': 6,
#    'bike_stands': 20,
#    'number': 331,
#    'address': 'GEORGES HENRI - AV GEORGES HENRI',
#    'name': '331 - GEORGES HENRI',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.842319, 4.406295],
#    'last_update': '2024-02-26T12:46:21+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.406295, 50.842319]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'fd3f54734ca782db7ce240b1ef69f44586226fb5',
#   'fields': {'available_bike_stands': 17,
#    'bike_stands': 22,
#    'number': 326,
#    'address': 'ADEPS - CHEE DE WAVRE / WAVERSESTEENWEG 2057',
#    'name': '326 - ADEPS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 5,
#    'position': [50.809406, 4.443777],
#    'last_update': '2024-02-26T12:46:51+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.443777, 50.809406]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '145eb11bd908b5351efdf433f341ebfed5bca597',
#   'fields': {'available_bike_stands': 15,
#    'bike_stands': 25,
#    'number': 212,
#    'address': 'THEO LAMBERT - BD THEO LAMBERT (FACE 66) / THEO LAMBERT LAAN (TEGENOVER 66)',
#    'name': '212 - THEO LAMBERT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.82701, 4.292098],
#    'last_update': '2024-02-26T12:45:05+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.292098, 50.82701]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'c2371b3c9f6d51534389171bb139c95c846990fd',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 19,
#    'number': 231,
#    'address': 'KERSBEEK - AV KERSBEEK 107 / KERSBEEKLAAN 107',
#    'name': '231 - KERSBEEK',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.805801, 4.3194],
#    'last_update': '2024-02-26T12:49:38+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.3194, 50.805801]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '96f74a455b50201ea897e3d82003043dbb6738e9',
#   'fields': {'available_bike_stands': 22,
#    'bike_stands': 30,
#    'number': 122,
#    'address': "GARE D'ETTERBEEK/STATION VAN ETTERBEEK - BOULEVARD GENERAL JACQUES/GENERAAL JACQUESLAAN",
#    'name': "122 - GARE D'ETTERBEEK",
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 8,
#    'position': [50.822207, 4.389325],
#    'last_update': '2024-02-26T12:50:40+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.389325, 50.822207]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b518f93a4091ecec4f4ffd1feff47152b181753d',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 25,
#    'number': 181,
#    'address': 'LOUIS TITZ - AVENUE DE LA CHASSE/ JACHTLAAN 182 - 184',
#    'name': '181 - LOUIS TITZ',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 13,
#    'position': [50.835723, 4.394395],
#    'last_update': '2024-02-26T12:49:12+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.394395, 50.835723]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'd30708e4dd134a031cc666e5dc09411d16840048',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 25,
#    'number': 125,
#    'address': 'GEORGES BRUGMANN - PLACE GEORGES BRUGMANN/GEORGES BRUGMANNPLEIN N° 10 - 11',
#    'name': '125 - GEORGES BRUGMANN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.817392, 4.354105],
#    'last_update': '2024-02-26T12:50:05+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.354105, 50.817392]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '8d7874a4e943ec06405d2e071742735caac75122',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 20,
#    'number': 335,
#    'address': 'THIRY - BD DE LA WOLUWE DVT 100',
#    'name': '335 - THIRY',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.854231, 4.444034],
#    'last_update': '2024-02-26T12:49:55+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.444034, 50.854231]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'a188e2bd1d7c6c80a36135c96463ff8263dc7e42',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 232,
#    'address': 'DOMAINE / DOMEIN - AV DU DOMAINE (FACE 150) / DOMEINELAAN (VOOR 150)',
#    'name': '232 - DOMAINE / DOMEIN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.810875, 4.329158],
#    'last_update': '2024-02-26T12:50:17+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.329158, 50.810875]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '24cc0b983f4aceeb25365d7a9a310082ce6530b4',
#   'fields': {'available_bike_stands': 14,
#    'bike_stands': 24,
#    'number': 191,
#    'address': 'ARTAN - RUE CLAYS',
#    'name': '191 - ARTAN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.853973, 4.38374],
#    'last_update': '2024-02-26T12:49:35+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.38374, 50.853973]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '8bddf6ddf8d90f7f1ee8bbefe5354aedef865c62',
#   'fields': {'available_bike_stands': 13,
#    'bike_stands': 25,
#    'number': 86,
#    'address': 'MAISON COMMUNALE DE JETTE GEMEENTEHUIS - Chau. de Wemmel / Wemmelsesteenweg 102',
#    'name': '086 - MAISON COMMUNALE DE JETTE GEMEENTEHUIS',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.876195, 4.324477],
#    'last_update': '2024-02-26T12:50:17+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.324477, 50.876195]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '137d9f0e0c6b2e1eb80bd95a28340630caf93152',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 25,
#    'number': 154,
#    'address': 'PLASKY - SQUARE EUGENE PLASKY (FACE 100) / EUGENE PLASKYSQUARE (TEGENOVER 100)',
#    'name': '154 - PLASKY/PLASKY',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 15,
#    'position': [50.851241, 4.396386],
#    'last_update': '2024-02-26T12:50:19+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.396386, 50.851241]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '958b80968e2b2db6566694ff0fe17da75fbc9083',
#   'fields': {'available_bike_stands': 13,
#    'bike_stands': 25,
#    'number': 208,
#    'address': 'MELBA - AV NELLIE MELBA (FACE 1 a 9) / NELLIE MELBALAAN (TEGENOVER 1 tot 9)',
#    'name': '208 - MELBA',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 12,
#    'position': [50.832565, 4.294311],
#    'last_update': '2024-02-26T12:51:04+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.294311, 50.832565]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '86c606243ff7787f5b28618b9952da9962fcbc98',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 20,
#    'number': 238,
#    'address': 'UNION SAINT-GILLOISE / SINT-GILLIS UNIE - CH DE BRUXELLES 366-362 / BRUSSELSESTEENWEG 366-362',
#    'name': '238 - UNION SAINT-GILLOISE / SINT-GILLIS UNIE',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.820278, 4.330802],
#    'last_update': '2024-02-26T12:50:38+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.330802, 50.820278]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'bd709909adf723954aa94c2042cee6a695d66dc8',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 40,
#    'number': 16,
#    'address': 'LOUISE/LOUIZA - PLACE LOUISE/LOUIZAPLEIN 53',
#    'name': '016 - LOUISE / LOUIZA',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 30,
#    'position': [50.835968, 4.355508],
#    'last_update': '2024-02-26T12:50:45+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.355508, 50.835968]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b53ba1d9e1a4eb8cbb124b2e9d7a54be6b2a4166',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 25,
#    'number': 123,
#    'address': 'BASCULE -  CHAUSSEE DE VLEURGAT (DEVANT 315 - 317) / VLEURGATSESTEENWEG  (N° 315 - 317)',
#    'name': '123 - BASCULE',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.817507, 4.366498],
#    'last_update': '2024-02-26T12:51:03+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.366498, 50.817507]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '0d8f2a8390c4d497d62fe07053eb6d2f62ec7715',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 25,
#    'number': 147,
#    'address': "EMILE MAX LYCEE/LYCEUM EMILE MAX - CHAUSSEE D'HAECHT/ HAACHTSESTEENWEG 226 - 230",
#    'name': '147 - EMILE MAX LYCEE/LYCEUM EMILE MAX',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.861874, 4.372146],
#    'last_update': '2024-02-26T12:49:26+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.372146, 50.861874]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '24a11b9f26c5945574222458ce5270db908bc5e2',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 20,
#    'number': 47,
#    'address': 'LES QUAIS/KAAIEN - QUAI A LA CHAUX/KALKKAAI 1-2',
#    'name': '047 - LES QUAIS / KAAIEN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.854714, 4.347151],
#    'last_update': '2024-02-26T12:50:49+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.347151, 50.854714]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '3c1bded9eda4c5a9c32571276bcd2829b4537277',
#   'fields': {'available_bike_stands': 18,
#    'bike_stands': 25,
#    'number': 312,
#    'address': 'CENTRE CULTUREL / CULTUREEL CENTRUM - BD DU SOUVERAIN FACE 282 / VORSTLAAN VOOR 282',
#    'name': '312 - CENTRE CULTUREL / CULTUREEL CENTRUM',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 6,
#    'position': [50.816948, 4.426551],
#    'last_update': '2024-02-26T12:49:21+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.426551, 50.816948]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '28277f5dfe8ff6667e67ac678b04d191826d1260',
#   'fields': {'available_bike_stands': 9,
#    'bike_stands': 25,
#    'number': 239,
#    'address': 'DARWIN - AV. BRUGMANN / BRUGMANNLAAN 139-147',
#    'name': '239 - DARWIN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.817777, 4.350406],
#    'last_update': '2024-02-26T12:50:31+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.350406, 50.817777]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '0bbcce6be67f7e39d0e994b285d91287440f1a25',
#   'fields': {'available_bike_stands': 14,
#    'bike_stands': 25,
#    'number': 182,
#    'address': 'BOILEAU - BOULEVARD SAINT MICHEL / SINT-MICHIELSLAAN',
#    'name': '182 - BOILEAU',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.83168, 4.404769],
#    'last_update': '2024-02-26T12:50:14+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.404769, 50.83168]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '2e8bc98a0f4a10084b5a66a446f816b12c3322cf',
#   'fields': {'available_bike_stands': 13,
#    'bike_stands': 22,
#    'number': 254,
#    'address': 'BASILIQUE / BASILIEK - AV JACQUES SERMON / JACUES SERMONLAAN',
#    'name': '254 - BASILIQUE / BASILIEK',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.867393, 4.320344],
#    'last_update': '2024-02-26T12:50:30+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.320344, 50.867393]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '8cf2d384e35a0714e93b8cf08122b59adcde2916',
#   'fields': {'available_bike_stands': 6,
#    'bike_stands': 20,
#    'number': 63,
#    'address': 'JULES CESAR - AVENUE DE TERVUREN DEVANT / TERVURENLAAN VOOR 278',
#    'name': '063 - JULES CESAR',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 14,
#    'position': [50.834705, 4.421643],
#    'last_update': '2024-02-26T12:49:52+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.421643, 50.834705]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '46a38a73982960fbb7555f7c92eabb9f8c8cf9a2',
#   'fields': {'available_bike_stands': 4,
#    'bike_stands': 20,
#    'number': 364,
#    'address': 'DOCKS BRUXSEL - AVENUE JULES VAN PRAETLAAN',
#    'name': '364 - DOCKS BRUXSEL',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 16,
#    'position': [50.879086, 4.374729],
#    'last_update': '2024-02-26T12:49:33+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.374729, 50.879086]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '44c146194949424888b92e3f343a0d6ae23f084f',
#   'fields': {'available_bike_stands': 12,
#    'bike_stands': 25,
#    'number': 15,
#    'address': 'MONTGOMERY - AVENUE DE TERVUREN / TERVURENLAAN 136-138',
#    'name': '015 - MONTGOMERY',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 13,
#    'position': [50.837036, 4.406826],
#    'last_update': '2024-02-26T12:49:24+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.406826, 50.837036]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '5e99d2788d1b84e5afd7c725f578b5d8ad509e44',
#   'fields': {'available_bike_stands': 21,
#    'bike_stands': 44,
#    'number': 179,
#    'address': 'CELTES/KELTEN - AVENUE DE TERVUEREN (FACE AU 17) / TERVURENLAAN (TEGENOVER 17)',
#    'name': '179 - CELTES/KELTEN',
#    'bonus': 'True',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 18,
#    'position': [50.839217, 4.398015],
#    'last_update': '2024-02-26T12:50:24+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.398015, 50.839217]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '5e81b4798ceb2657cf5d9d431f30d200d69444c3',
#   'fields': {'available_bike_stands': 18,
#    'bike_stands': 25,
#    'number': 42,
#    'address': "PORTE DE NINOVE / NINOOFSEPOORT - Pl. de Ninove x Bd de l'Abattoir / Ninoofseplein x Slachthuislaan",
#    'name': '042 - PORTE DE NINOVE / NINOOFSEPOORT',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 7,
#    'position': [50.84851, 4.338064],
#    'last_update': '2024-02-26T12:49:50+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.338064, 50.84851]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'ccadf97e1438ed1abeb0a3fb288a5f766a7206c1',
#   'fields': {'available_bike_stands': 11,
#    'bike_stands': 22,
#    'number': 148,
#    'address': 'GARE MEISER / MEISER STATION - AVENUE ROGIER/ ROGIERLAAN 377 - 379',
#    'name': '148 - GARE MEISER/MEISER STATION',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 10,
#    'position': [50.855629, 4.394807],
#    'last_update': '2024-02-26T12:50:32+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.394807, 50.855629]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'b9adac903756ae7a543c790719f5c3add942a0a4',
#   'fields': {'available_bike_stands': 8,
#    'bike_stands': 20,
#    'number': 327,
#    'address': 'SIBELGA - QUAI DES USINES / WERKHUIZENKAAI 16',
#    'name': '327 - SIBELGA',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 11,
#    'position': [50.874082, 4.362205],
#    'last_update': '2024-02-26T12:49:48+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.362205, 50.874082]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': 'fcb06f8b2e8885c44d5b21b3e51c4568518865b0',
#   'fields': {'available_bike_stands': 16,
#    'bike_stands': 25,
#    'number': 163,
#    'address': 'CHAZAL - AVENUE ERNEST CAMBIER (FACE 7)/ ERNEST CAMBIERLAAN (TEGENOVER 7)',
#    'name': '163 - CHAZAL/CHAZAL',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.859112, 4.39157],
#    'last_update': '2024-02-26T12:50:07+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.39157, 50.859112]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '5e4f5c3b767b2e15827c2686434dcb06db0bee23',
#   'fields': {'available_bike_stands': 10,
#    'bike_stands': 20,
#    'number': 334,
#    'address': 'MARCEL THIRY - AV MARCEL THIRY FACE 23',
#    'name': '334 - MARCEL THIRY',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 9,
#    'position': [50.855593, 4.439625],
#    'last_update': '2024-02-26T12:49:22+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.439625, 50.855593]}},
#  {'datasetid': 'jcdecaux-bike-stations-data-rt',
#   'recordid': '84e810acb99e02b68fab53b026991b46f4e63ba1',
#   'fields': {'available_bike_stands': 6,
#    'bike_stands': 25,
#    'number': 276,
#    'address': 'CROIX DE GUERRES / OORLOGSKRUISEN - AVENUE DES CROIX DE GUERRE / OORLOGSKRUISENLAAN 116',
#    'name': '276 - CROIX DE GUERRES / OORLOGSKRUISEN',
#    'bonus': 'False',
#    'banking': 'False',
#    'contract_name': 'Bruxelles-Capitale',
#    'status': 'OPEN',
#    'available_bikes': 19,
#    'position': [50.889748, 4.380755],
#    'last_update': '2024-02-26T12:50:09+00:00'},
#   'geometry': {'type': 'Point', 'coordinates': [4.380755, 50.889748]}}]

# %% [markdown]
# ## Stations sorted by name
#
# We can sort the stations by name in alphabetical order by first making a function that for each entry of the list returns the station name. Then we have just to sort the list.

# %%
def get_station_name(station):
    "Return the name of a station (station is a dictionary from the API)"
    station_name_raw = station['fields']['name']
    # Remove the station number from the name
    station_name = station_name_raw.split('-', maxsplit = 1)[1].strip()
    return station_name

get_station_name(stations[1])
# Out:
# 'VETERANS COLONIAUX / KOLONIALE VETERANEN'

# %% [markdown]
# ### Loops
# To get all the station names we can:
# 1. Either apply the function to each element of the list manually
# 2. Or use a loop to do it for us

# %%
#1 .  apply the function to each element of the list manually
station_name_list = [get_station_name(stations[0]),
                     get_station_name(stations[1]),
                     get_station_name(stations[2]),
                     get_station_name(stations[3]),
                     get_station_name(stations[4]),
                     get_station_name(stations[5]),
                     get_station_name(stations[6]),
                     get_station_name(stations[7]),
                     get_station_name(stations[8]),
                     # ...
                     get_station_name(stations[49])]
station_name_list
# Out:
# ['PETER BENOIT',
#  'VETERANS COLONIAUX / KOLONIALE VETERANEN',
#  'JOSEPH II / JOZEF II',
#  'DUBOIS',
#  'JARDIN MASSART',
#  'CAMPUS CERIA / CAMPUS VAN CERIA',
#  'VANDENDRIESCH',
#  'BIESTEBROECK / BIESTEBROEK',
#  'FONTAINAS',
#  'CROIX DE GUERRES / OORLOGSKRUISEN']

# %%
# 2. use a loop to do it for us

station_name_list = [] # initialize empty list
for x in stations: # loop through each element of the list list
    name = get_station_name(x) # get for each station the name
    station_name_list.append(name) # add it to the list

# %%
# 2. use a loop to do it for us (loop inside a list = list comprehension)
station_name_list = [get_station_name(x) for x in stations]

# %%
# And now just sort it
sorted(station_name_list)
# Out:
# ['ADEPS',
#  'ARTAN',
#  'BASCULE',
#  'BASILIQUE / BASILIEK',
#  'BERKENDAEL / BERKENDAAL',
#  'BIESTEBROECK / BIESTEBROEK',
#  'BOILEAU',
#  'CAMPUS CERIA / CAMPUS VAN CERIA',
#  'CELTES/KELTEN',
#  'CENTRE CULTUREL / CULTUREEL CENTRUM',
#  'CHAZAL/CHAZAL',
#  'CLEMENCEAU',
#  'COLONEL BOURG/KOLONEL BOURG',
#  'CROIX DE GUERRES / OORLOGSKRUISEN',
#  'DARWIN',
#  'DOCKS BRUXSEL',
#  'DOMAINE / DOMEIN',
#  'DUBOIS',
#  'EMILE MAX LYCEE/LYCEUM EMILE MAX',
#  'FONTAINAS',
#  "GARE D'ETTERBEEK",
#  'GARE DU NORD/NOORDSTATION',
#  'GARE MEISER/MEISER STATION',
#  'GEORGES BRUGMANN',
#  'GEORGES HENRI',
#  'HANKAR',
#  'HOUZEAU',
#  'JARDIN MASSART',
#  'JOSEPH II / JOZEF II',
#  'JULES CESAR',
#  'KERSBEEK',
#  'LES QUAIS / KAAIEN',
#  'LOUIS TITZ',
#  'LOUISE / LOUIZA',
#  'MAISON COMMUNALE DE JETTE GEMEENTEHUIS',
#  'MARCEL THIRY',
#  'MELBA',
#  'MONTGOMERY',
#  'PETER BENOIT',
#  'PLACE DAILLY/DAILLYPLEIN',
#  'PLASKY/PLASKY',
#  'PORTE DE FLANDRE / VLAAMSEPOORT',
#  'PORTE DE NINOVE / NINOOFSEPOORT',
#  'SIBELGA',
#  'THEO LAMBERT',
#  'THIRY',
#  'THOMAS BALIS',
#  'UNION SAINT-GILLOISE / SINT-GILLIS UNIE',
#  'VANDENDRIESCH',
#  'VETERANS COLONIAUX / KOLONIALE VETERANEN']

# %% [markdown]
# # Make a dictionary with the bike stands names + # of available bikes

# %%
station1 = stations[3] #retrieve a station
get_station_name(station1) #name
# Out:
# 'DUBOIS'

# %%
station1['fields']['available_bikes'] # Number of bikes available
# Out:
# 15

# %%
dico_number_bikes = {} #initialize empty dictionary
#construct with a for loop
for station in stations:
    dico_number_bikes[get_station_name(station)] = station['fields']['available_bikes']

# %%
dico_number_bikes
# Out:
# {'PETER BENOIT': 12,
#  'VETERANS COLONIAUX / KOLONIALE VETERANEN': 14,
#  'JOSEPH II / JOZEF II': 11,
#  'DUBOIS': 15,
#  'JARDIN MASSART': 5,
#  'CAMPUS CERIA / CAMPUS VAN CERIA': 9,
#  'VANDENDRIESCH': 8,
#  'BIESTEBROECK / BIESTEBROEK': 8,
#  'FONTAINAS': 28,
#  'BERKENDAEL / BERKENDAAL': 15,
#  'PLACE DAILLY/DAILLYPLEIN': 16,
#  'COLONEL BOURG/KOLONEL BOURG': 15,
#  'CLEMENCEAU': 22,
#  'HANKAR': 9,
#  'HOUZEAU': 10,
#  'THOMAS BALIS': 9,
#  'GARE DU NORD/NOORDSTATION': 22,
#  'PORTE DE FLANDRE / VLAAMSEPOORT': 12,
#  'GEORGES HENRI': 14,
#  'ADEPS': 5,
#  'THEO LAMBERT': 10,
#  'KERSBEEK': 7,
#  "GARE D'ETTERBEEK": 8,
#  'LOUIS TITZ': 13,
#  'GEORGES BRUGMANN': 14,
#  'THIRY': 11,
#  'DOMAINE / DOMEIN': 9,
#  'ARTAN': 10,
#  'MAISON COMMUNALE DE JETTE GEMEENTEHUIS': 12,
#  'PLASKY/PLASKY': 15,
#  'MELBA': 12,
#  'UNION SAINT-GILLOISE / SINT-GILLIS UNIE': 7,
#  'LOUISE / LOUIZA': 30,
#  'BASCULE': 14,
#  'EMILE MAX LYCEE/LYCEUM EMILE MAX': 14,
#  'LES QUAIS / KAAIEN': 9,
#  'CENTRE CULTUREL / CULTUREEL CENTRUM': 6,
#  'DARWIN': 14,
#  'BOILEAU': 11,
#  'BASILIQUE / BASILIEK': 7,
#  'JULES CESAR': 14,
#  'DOCKS BRUXSEL': 16,
#  'MONTGOMERY': 13,
#  'CELTES/KELTEN': 18,
#  'PORTE DE NINOVE / NINOOFSEPOORT': 7,
#  'GARE MEISER/MEISER STATION': 10,
#  'SIBELGA': 11,
#  'CHAZAL/CHAZAL': 9,
#  'MARCEL THIRY': 9,
#  'CROIX DE GUERRES / OORLOGSKRUISEN': 19}

# %%
# other way via dictionary comprehension
dico_number_bikes = {get_station_name(station) : station['fields']['available_bikes'] for station in stations}
dico_number_bikes
# Out:
# {'PETER BENOIT': 12,
#  'VETERANS COLONIAUX / KOLONIALE VETERANEN': 14,
#  'JOSEPH II / JOZEF II': 11,
#  'DUBOIS': 15,
#  'JARDIN MASSART': 5,
#  'CAMPUS CERIA / CAMPUS VAN CERIA': 9,
#  'VANDENDRIESCH': 8,
#  'BIESTEBROECK / BIESTEBROEK': 8,
#  'FONTAINAS': 28,
#  'BERKENDAEL / BERKENDAAL': 15,
#  'PLACE DAILLY/DAILLYPLEIN': 16,
#  'COLONEL BOURG/KOLONEL BOURG': 15,
#  'CLEMENCEAU': 22,
#  'HANKAR': 9,
#  'HOUZEAU': 10,
#  'THOMAS BALIS': 9,
#  'GARE DU NORD/NOORDSTATION': 22,
#  'PORTE DE FLANDRE / VLAAMSEPOORT': 12,
#  'GEORGES HENRI': 14,
#  'ADEPS': 5,
#  'THEO LAMBERT': 10,
#  'KERSBEEK': 7,
#  "GARE D'ETTERBEEK": 8,
#  'LOUIS TITZ': 13,
#  'GEORGES BRUGMANN': 14,
#  'THIRY': 11,
#  'DOMAINE / DOMEIN': 9,
#  'ARTAN': 10,
#  'MAISON COMMUNALE DE JETTE GEMEENTEHUIS': 12,
#  'PLASKY/PLASKY': 15,
#  'MELBA': 12,
#  'UNION SAINT-GILLOISE / SINT-GILLIS UNIE': 7,
#  'LOUISE / LOUIZA': 30,
#  'BASCULE': 14,
#  'EMILE MAX LYCEE/LYCEUM EMILE MAX': 14,
#  'LES QUAIS / KAAIEN': 9,
#  'CENTRE CULTUREL / CULTUREEL CENTRUM': 6,
#  'DARWIN': 14,
#  'BOILEAU': 11,
#  'BASILIQUE / BASILIEK': 7,
#  'JULES CESAR': 14,
#  'DOCKS BRUXSEL': 16,
#  'MONTGOMERY': 13,
#  'CELTES/KELTEN': 18,
#  'PORTE DE NINOVE / NINOOFSEPOORT': 7,
#  'GARE MEISER/MEISER STATION': 10,
#  'SIBELGA': 11,
#  'CHAZAL/CHAZAL': 9,
#  'MARCEL THIRY': 9,
#  'CROIX DE GUERRES / OORLOGSKRUISEN': 19}

# %% [markdown]
# ## Check the number of stations have at least 20 available bikes

# %%
Number = 0 # initialize counter to 0
# loop over a dictionary with .items()
for key,value in dico_number_bikes.items():
    if value >= 20 :
        print('Station ' + key + ' has ' + str(value) + ' bikes available')
        Number += 1 # add 1 to counter (is the same as writing Number = Number + 1)

print('\n') #print blank line
print('In total ' + str(Number) +' stations have at least 20 bikes available')
# Out:
# Station FONTAINAS has 28 bikes available
# Station CLEMENCEAU has 22 bikes available
# Station GARE DU NORD/NOORDSTATION has 22 bikes available
# Station LOUISE / LOUIZA has 30 bikes available
#
#
# In total 4 stations have at least 20 bikes available

# %% [markdown]
# ## Exercises
# Note: You will have to adapt the `URL_Villo` and make a new request to get all the stations instead of the 50 first ones.
#
# 1. How many bike stands are there in total ?
# 2. How many bikes are available **at this moment** ?
# 3. Write a function that returns the `stations` list at the **current** time.
# 3. Write a function that returns the **current** total number of bikes available.
# 4. Write a function that returns the **current** number of bikes available in an arbitrary station (for instance '351 - ULB').
# 6. Write a function that checks for each station in `dico_number_bikes` if (in the meanwhile) anyone took or brought back a bike.
#
# ### Bonus
#
# 1. Write a function that will check every 10 seconds if someone took or brought back a bike in any station during 2 minutes.
# 2. Find the currently OPEN station that is the least used/ that had the longest time ago an update.

# %%
# Redo an API request to get all the bike stations

# %%
# Solution
URL_Villo = "https://public.opendatasoft.com/api/records/1.0/search/?dataset=jcdecaux-bike-stations-data-rt&q=&facet=banking&facet=name&exclude.name=BORNE+TEST+ALLEE+VERTE&exclude.name=BORNE+ATELIER+MECANOS+SPL&facet=bonus&facet=status&facet=contract_name&refine.contract_name=Bruxelles-Capitale&rows=1000"
response = requests.get(URL_Villo)  # Retrieve the response
data = response.json()  # Parse from JSON

# %% [markdown]
#     1. How many bike stands are there in total ?

# %%
# Solution
len(data['records'])
# Out:
# 351

# %% [markdown]
#     2. How many bikes are available at this moment ?
#
# *Hint: to answer this question, you need to have the latest info available (otherwise it is not "at this moment") => make a new API call and compute answer directly after it)*

# %%
# Solution
response = requests.get(URL_Villo)  # Retrieve the response
data = response.json()  # Parse from JSON
stations = data['records']
total = 0
for stat in stations:
    total = total + stat['fields']['available_bikes']

# %%
total
# Out:
# 3807

# %% [markdown]
#     3. Write a function that returns the stations list at the current time.

# %%
# Solution
def get_villo_stations():
    "Get new data from the Villo API, for the given Villo API URL."

    response = requests.get(URL_Villo)  # Retrieve the response
    data = response.json()  # Parse from JSON
    stations = data['records']
    return stations

#test:
stations = get_villo_stations()
print(len(stations))
# Out:
# 351

# %% [markdown]
#     4. Write a function that returns the current total number of bikes available.
# *Hint: Same as before but write it as a function*

# %%
# Solution
def current_available_bikes():
    stations = get_villo_stations()
    total_bikes_available = 0 #initialize counter at 0

    for station in stations:
        # Loop through all stations and add the number of availaible bikes to counter
        total_bikes_available += station['fields']['available_bikes']

    return(total_bikes_available)

#test
current_available_bikes()
# Out:
# 3807

# %% [markdown]
#     5. Write a function that returns the current number of bikes available in an arbitrary station (for instance 'ULB').

# %%
# Solution
def bikes_at_station(stations, station_to_find = 'ULB'):

    for station in stations:
        if get_station_name(station) == station_to_find:
            # This is the station we are looking for
            return station['fields']['available_bikes']

# %%
bikes_at_station(get_villo_stations(),'ULB')
# Out:
# 20

# %%
bikes_at_station(stations = get_villo_stations())
# Out:
# 20

# %% [markdown]
#     6. Check for each station in `dico_number_bikes` if (in the meanwhile) anyone took or brought back a bike.

# %%
#Solution
stations = get_villo_stations()
for station, bikes in dico_number_bikes.items():
    now = bikes_at_station(stations,station)
    if bikes != now:
        print(f'For station {station} there were {bikes} bikes and now there are {now} bikes')

# %% [markdown]
# **Bonus**
#
#     1. Write a function that will check every 10 seconds if someone took or brought back a bike in any station during 2 minutes.
# *Hint: use python package time and the functionality time.sleep(10) to wait 10 seconds between each call and use package datetime and function datetime.datetime.now() to print the time stamp at each step*

# %%
#Solution
import time, datetime
def Check_changes_10s():
    stations = get_villo_stations()
    dico_number_bikes_init = {get_station_name(station) : station['fields']['available_bikes'] for station in stations}
    print('Start at: ' + str(datetime.datetime.now()))
    for i in range(12): # do 12 times (10 sec * 12 = 120 sec = 2 min)
        time.sleep(10)
        print(f'Loop {i} at {str(datetime.datetime.now())}')
        stations = get_villo_stations()
        dico_number_bikes_new = {get_station_name(station) : station['fields']['available_bikes'] for station in stations}
        for station, bikes in dico_number_bikes_new.items():
            if bikes != dico_number_bikes_init[station]:
                print(f'For station {station} there were {dico_number_bikes_init[station]} bikes and now there are {bikes} bikes')
        dico_number_bikes_init = dico_number_bikes_new

# %%
Check_changes_10s()

# %% [markdown]
# 2. Find the currently OPEN station that is the least used/ that had the longest time ago an update.

# %%
# Solution
def find_least_used(stations = get_villo_stations()):
    # initialize with time in future
    last_update_time = '2200-01-01T00:00:00+00:00'
    for station in stations:  # loop over stations
        if station['fields']['last_update'] < last_update_time and station['fields']['status'] == 'OPEN': # check update time smaller and still open
            last_updated = station
            last_update_time = station['fields']['last_update']
    print(f'Station {get_station_name(last_updated)} was last used at time {last_update_time}')
    return last_updated

# %%
find_least_used()
# Out:
# Station AUBERGE DE JEUNESSE was last used at time 2023-12-04T10:06:45+00:00
# {'datasetid': 'jcdecaux-bike-stations-data-rt',
#  'recordid': 'e4e47ef9669d7bdb54b89b98ffabfe35f31ef76f',
#  'fields': {'available_bike_stands': 6,
#   'bike_stands': 25,
#   'number': 192,
#   'address': 'AUBERGE DE JEUNESSE - RUE DELAUNOY/STRAAT ,67',
#   'name': '192 - AUBERGE DE JEUNESSE',
#   'bonus': 'False',
#   'banking': 'False',
#   'contract_name': 'Bruxelles-Capitale',
#   'status': 'OPEN',
#   'available_bikes': 19,
#   'position': [50.851562, 4.332924],
#   'last_update': '2023-12-04T10:06:45+00:00'},
#  'geometry': {'type': 'Point', 'coordinates': [4.332924, 50.851562]}}
